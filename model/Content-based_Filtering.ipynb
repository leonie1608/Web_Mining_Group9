# %% [markdown]
# # Content-Based Filtering
# with following Model:
# - TF-IDF with Cosine Similarity

# %% [markdown]
# ### Import

# %%
# Install the surprise package
# !pip install -q -U scikit-surprise
from surprise import Dataset, Reader
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import arff
from surprise import KNNWithMeans
from surprise.dataset import DatasetAutoFolds
from surprise.model_selection import GridSearchCV
from surprise import KNNBasic
from surprise import SVD
from surprise.model_selection import cross_validate
from surprise import accuracy
import random
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
#from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
nltk.download('stopwords')
from collections import namedtuple
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Leonie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Data Preparation and Preprocessing Text

# %%
path = os.path.expanduser('../data/data_kindle_preprocessed_smaller.xlsx')
data_preprocessed = pd.read_excel(path, index_col=[0], dtype={'publication_year': str, 'book_info': str})

# %%
data_preprocessed.head()
# Out:
#         rating      reviewerID        asin  \
# 527748       4  A1TVJ9WDRP0UZS  B00HY2KN04
# 12432        5  A3IQ0P3M39IY8U  B004BLJ9IS
# 438646       5   AIQWMQ4JWKZ3T  B00FQAQQ9I
# 620082       4  A3CMIEYL0TJLC2  B00K31DCD8
# 590077       5  A1L9WQBSQ5SEFE  B00JD5BO8K
#
#                                                     title  \
# 527748  Just Jelly Beans and Jealousy (The Reed Brothe...
# 12432    The You I&ve Always Dreamed Of (Finding Famil...
# 438646  Wyoming Wildflowers: The Beginning: A Prequel ...
# 620082  Finding My Prince Charming (The Prince Charmin...
# 590077             Cowboy Wedding Mix-up - Kindle edition
#
#                                       brand language print_length_category  \
# 527748    Visit Amazon's Tammy Falkner Page  English                 small
# 12432       Visit Amazon's Alison Kent Page  English                 small
# 438646  Visit Amazon's Patricia McLinn Page  English                 small
# 620082     Visit Amazon's J. S. Cooper Page  English                 small
# 590077       Visit Amazon's JT Schultz Page  English                 small
#
#        publication_year                                    category_string  \
# 527748             2014  Kindle Store, Kindle eBooks, Literature & Fiction
# 12432              2010  Kindle Store, Kindle eBooks, Literature & Fiction
# 438646             2014  Kindle Store, Kindle eBooks, Literature & Fiction
# 620082             2014  Kindle Store, Kindle eBooks, Literature & Fiction
# 590077             2014               Kindle Store, Kindle eBooks, Romance
#
#        paid_free                                          book_info
# 527748      Free  Kindle Store, Kindle eBooks, Literature & Fict...
# 12432       Paid  Kindle Store, Kindle eBooks, Literature & Fict...
# 438646      Free  Kindle Store, Kindle eBooks, Literature & Fict...
# 620082      Paid  Kindle Store, Kindle eBooks, Literature & Fict...
# 590077      Paid  Kindle Store, Kindle eBooks, Romance  Visit Am...

# %%
# used in case for content analysis

def preprocess_text(text):
    # lowercasing
    lowercased_text = text.lower()

    # cleaning 
    import re 
    remove_punctuation = re.sub(r'[^\w\s]', '', lowercased_text)
    remove_white_space = remove_punctuation.strip()

    # Tokenization = Breaking down each sentence into an array
    from nltk.tokenize import word_tokenize
    tokenized_text = word_tokenize(remove_white_space)

    # Stop Words/filtering = Removing irrelevant words
    from nltk.corpus import stopwords
    stopwords = set(stopwords.words('english'))
    stopwords_removed = [word for word in tokenized_text if word not in stopwords]

    # Stemming = Transforming words into their base form
    from nltk.stem import PorterStemmer
    ps = PorterStemmer()
    stemmed_text = [ps.stem(word) for word in stopwords_removed]
    
    return stemmed_text  # Return only the stemmed text


# Ensure the 'book_info' column is treated as strings
data_preprocessed['book_info'] = data_preprocessed['book_info'].astype(str)

# Apply preprocess_text function to book_info
data_preprocessed['book_info'] = data_preprocessed['book_info'].apply(preprocess_text)

print(data_preprocessed['book_info'])
# Out:
# 527748     [kindl, store, kindl, ebook, literatur, fictio...
# 12432      [kindl, store, kindl, ebook, literatur, fictio...
# 438646     [kindl, store, kindl, ebook, literatur, fictio...
# 620082     [kindl, store, kindl, ebook, literatur, fictio...
# 590077     [kindl, store, kindl, ebook, romanc, visit, am...
#                                  ...
# 215730     [kindl, store, kindl, ebook, literatur, fictio...
# 1133251    [kindl, store, kindl, ebook, literatur, fictio...
# 1092850    [kindl, store, kindl, ebook, romanc, visit, am...
# 283061     [kindl, store, kindl, ebook, romanc, visit, am...
# 1171136    [kindl, store, kindl, ebook, literatur, fictio...
# Name: book_info, Length: 11639, dtype: object

# %%
#create subset of data_preprocessing to create new subset of columns
data_contentBased = data_preprocessed[["asin", "book_info"]]

# %%
data_contentBased['book_info'] = data_contentBased['book_info'].apply(lambda x: ' '.join(x))
# Out:
# C:\Users\Leonie\AppData\Local\Temp\ipykernel_12356\2135891888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_contentBased['book_info'] = data_contentBased['book_info'].apply(lambda x: ' '.join(x))

# %%
data_contentBased
# Out:
#                asin                                          book_info
# 527748   B00HY2KN04  kindl store kindl ebook literatur fiction visi...
# 12432    B004BLJ9IS  kindl store kindl ebook literatur fiction visi...
# 438646   B00FQAQQ9I  kindl store kindl ebook literatur fiction visi...
# 620082   B00K31DCD8  kindl store kindl ebook literatur fiction visi...
# 590077   B00JD5BO8K  kindl store kindl ebook romanc visit amazon jt...
# ...             ...                                                ...
# 215730   B00AMOOE0Q  kindl store kindl ebook literatur fiction visi...
# 1133251  B0196TRK8K  kindl store kindl ebook literatur fiction visi...
# 1092850  B0173QJGLW  kindl store kindl ebook romanc visit amazon ta...
# 283061   B00C16YL10  kindl store kindl ebook romanc visit amazon wi...
# 1171136  B01BA8ZTBA  kindl store kindl ebook literatur fiction visi...
#
# [11639 rows x 2 columns]

# %% [markdown]
# # Content Recommender System

# %% [markdown]
# ### With TF-IDF Verctorizer and Cosine Similarity

# %%
# Function to get top 10 similar products for each product in the dataframe
def tf_idf_recommender(data_preprocessed):
    n_recommendations=10
    
    # Compute TF-IDF matrix
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(data_preprocessed['book_info'])
    
    # Calculate cosine similarity matrix
    cosine_sim_matrix = cosine_similarity(tfidf_matrix)
    
    # Create a DataFrame for cosine similarity matrix for better readability
    cosine_sim_df = pd.DataFrame(cosine_sim_matrix, index=data_preprocessed.index, columns=data_preprocessed.index)

    # Recommendation
    # Create a dictionary to store similar ASINs for each ASIN
    similar_asins_dict = {}
    
    # Iterate through each ASIN
    for i, asin in enumerate(data_preprocessed['asin']):
        # Find index of current ASIN
        asin_index = data_preprocessed.index[i]
        
        # Find top similar ASINs based on similarity scores
        similar_asins_indices = cosine_sim_df[asin_index].argsort()[:-n_recommendations-1:-1]  # Top n similar ASINs
        similar_asins = data_preprocessed.iloc[similar_asins_indices]['asin'].tolist()
        
        # Store similar ASINs in the dictionary
        similar_asins_dict[asin] = similar_asins

    # Create a new dictionary for filtered recommendations
    filtered_recommendations = {}
    
    # Iterate over the original recommendations
    for key, value in similar_asins_dict.items():
        # Filter out values that are similar to the key
        filtered_values = [v for v in value if v != key]
        # Add to the filtered recommendations if there are any remaining values
        if filtered_values:
            filtered_recommendations[key] = filtered_values

    # Iterate over the dictionary and remove duplicate values
    for key, value in filtered_recommendations.items():
        filtered_recommendations[key] = list(set(value))
    
    # Print or use similar_asins_dict as needed
    return filtered_recommendations

# %%
tf_idf_recommendations = tf_idf_recommender(data_contentBased)

# %%
tf_idf_recommendations
# Out:
# {'B00HY2KN04': ['B00JORD84K', 'B00HVRDDQ8'],
#  'B004BLJ9IS': ['B00MJOVIDI', 'B00DMR0NTQ'],
#  'B00FQAQQ9I': ['B00457VKIA'],
#  'B00K31DCD8': ['B00HNWEA9K', 'B00N8G9PFO'],
#  'B00JD5BO8K': ['B00IHQAYYQ', 'B019UH78JY', 'B00HY0GTYK'],
#  'B005OY0JFI': ['B00DD88VJI', 'B006S3FAR6'],
#  'B00CDZU7SU': ['B00HE4Z51Y',
#   'B00BL6CDCA',
#   'B0090W7ZB6',
#   'B00C2L7N4G',
#   'B00P32ZUAK',
#   'B0069FJE4S',
#   'B005LVV6DI'],
#  'B01CIWXAQI': ['B01HFUF1GK'],
#  'B00UKKMKD0': ['B00V8CETHO'],
#  'B00IU087O8': ['B00FVDMDOC', 'B00EJXIO7U'],
#  'B014HGM9YM': ['B00UDQTS40'],
#  'B00ZDHZKKA': ['B01DTBHY46', 'B01FP256UQ'],
#  'B00BR3AT9G': ['B00L9Q1Y7C'],
#  'B01FEI4OAE': ['B01EYW7SAE', 'B00H0NX3KE', 'B01FSDI7H6', 'B004WSQNBG'],
#  'B00N05R8GG': ['B005S1XTEA', 'B00H2ZK6FU'],
#  'B00QOWH556': ['B00J9YWGTQ', 'B00R1O4KWW'],
#  'B00JNELJPY': ['B00JNK590Y', 'B00MZI379Q', 'B00KBN0F3S'],
#  'B00E4T0P3U': ['B004W0C520', 'B01EJ2BV0W'],
#  'B00KNGAX0I': ['B00O3GPDKO', 'B00MQDVWL0', 'B00HGI16I4'],
#  'B00DFIE9NI': ['B00CNQ7BG0', 'B00QE1J5HI', 'B00IWTSKBW', 'B00BRUQ7JK'],
#  'B00D64UYTE': ['B01FODPWPA'],
#  'B00CULFBGK': ['B00TC1W3D0', 'B00F5DF9QC'],
#  'B00AV8SY7C': ['B00GU460T0'],
#  'B00MT79E0Y': ['B00QI8BV9W', 'B00LNMM6SI'],
#  'B00I11X2PK': ['B00K3WXIFE', 'B00MS9DVPM', 'B00KTE0JJY'],
#  'B00O3GPDKO': ['B00MQDVWL0', 'B00KNGAX0I', 'B00HGI16I4'],
#  'B00GYLAZJU': ['B00RE0O2OO',
#   'B00J3BRW6C',
#   'B00E7824EQ',
#   'B00I2VUKKY',
#   'B00SJ7LQ9K'],
#  'B00IGEIAB8': ['B00E4T0P3U', 'B0081CUVIU', 'B01EJ2BV0W'],
#  'B01GQW4UQ0': ['B019B6TWFC', 'B00VD0432M', 'B00KUJCVLC'],
#  'B0069FJE4S': ['B00HE4Z51Y',
#   'B005DPIINI',
#   'B0090W7ZB6',
#   'B00C2L7N4G',
#   'B00P32ZUAK',
#   'B005LVV6DI',
#   'B009BZFQ4U'],
#  'B00GW3TPWI': ['B00N6CY244', 'B00MDACG9I'],
#  'B005MUEXWE': ['B007WFQX9S', 'B00BEOZCJU', 'B00I11X2PK', 'B00JX7UVFU'],
#  'B00DRF2602': ['B017J0798O'],
#  'B00B8KYP84': ['B00MQFVDLC'],
#  'B00OYWP6G8': ['B00L2K4D0U'],
#  'B00BFQDEBU': ['B007YIZ2YA', 'B018BDHGS6'],
#  'B00I1SQBUQ': ['B00WQLAI7Q'],
#  'B00E9ZVG7S': ['B00538W83Q', 'B00BD63EIK', 'B00BMU2VEK', 'B00DH8T4DG'],
#  'B00L9Q1Y7C': ['B010W8KGVM', 'B00BR3AT9G'],
#  'B01EKIELGG': ['B00F70LNO0', 'B01DJZ7G5E', 'B014LZJVAE', 'B006S3FAR6'],
#  'B00GW9H8XA': ['B00EGJ334Q', 'B00KFG51O4'],
#  'B00TJCFIFM': ['B0117VIQRE',
#   'B00S776ER6',
#   'B00RXZXOWQ',
#   'B00ZTMRHQ4',
#   'B00T0WXD8K',
#   'B00U89TGNU',
#   'B00RYC3A3Q',
#   'B00VH4UFMG'],
#  'B00MJOVIDI': ['B013KWCLA6'],
#  'B00IJYII4E': ['B00BCQ6PYQ', 'B00YJCJGEG', 'B00PPDJ7OW', 'B00EJR4HVS'],
#  'B012TE6QVG': ['B0196TRK8K', 'B00WZSQ734', 'B015Y80IGS'],
#  'B00S6ROWI0': ['B00XAGLZWS', 'B01BW83B72', 'B016WM67OC'],
#  'B00BND1UTS': ['B00BW73VVU', 'B00ESPZ2C4', 'B00BEOYH0U', 'B00DVYIQDA'],
#  'B004XW3LLQ': ['B0067LH1QC'],
#  'B00E9MCRLA': ['B00H5GMYBA'],
#  'B00QILNL9M': ['B00LJAZ7W6', 'B00CAW3G66', 'B00H17FQCC', 'B00UY3LLY2'],
#  'B019OYETT0': ['B00SW2TWJS'],
#  'B00EGJE43K': ['B01G89E5OS', 'B0089YQPI0', 'B00H9KEAKA', 'B00DE3XL4W'],
#  'B005PP3DVS': ['B01E8H55ZA', 'B00IVD0BD4', 'B00C9L5L52'],
#  'B009G9LJKG': ['B008HUP9NI', 'B0092WQ7BS'],
#  'B00M8KMNUK': ['B01018NMMI', 'B00F0SI3E2', 'B00KVQQYRG'],
#  'B00RZT2U5W': ['B00TWUUBUI'],
#  'B00TZ8TK54': ['B00F5FBRD4', 'B00U2521PU'],
#  'B00OTNSM4U': ['B00HN9G1BS'],
#  'B004AM59T6': ['B004EYT0UO', 'B004HO5ZY6', 'B003AKY45Y', 'B004FEF9XK'],
#  'B0076FKQGU': ['B00CP7M572', 'B007GXQ78S'],
#  'B0026REA92': ['B00GG16KI8', 'B00JTCDAPC', 'B00MARJTYO', 'B00PYOE24C'],
#  'B00H7IM66Y': ['B0054QCKDA', 'B00FVIXS5K', 'B00QXUN5Y4'],
#  'B00DD88VJI': ['B00QE466KY', 'B00BMU2VEK', 'B00WDD5IKO'],
#  'B00MVK5RIW': ['B00QIV6JXM'],
#  'B01G2YFYG2': ['B01C7NYWBK', 'B01CF7VTQE'],
#  'B00YLPMA8K': ['B00Y9H7M0G',
#   'B00SHV3CNG',
#   'B00I1U1FP0',
#   'B010MPIN1K',
#   'B01CUOPVZW',
#   'B00PSPFPSO'],
#  'B0051EZBRM': ['B005JVSU2U'],
#  'B00RYIXX6Y': ['B00TFX0HYC', 'B00V9525BC', 'B00SWF7O7M'],
#  'B00VVMC2FW': ['B00K9O53UO', 'B00HTJJST4', 'B005UJR9JQ', 'B00SVY34YG'],
#  'B005GMUU8O': ['B00EAHZR5W', 'B00H3QI9BQ'],
#  'B01A164PSU': ['B017O4W3V8', 'B00DXQ08QO', 'B00RO392V4'],
#  'B00XB6M0OY': ['B01C0UBDEO', 'B00T72LZN8', 'B017RFCQ5C'],
#  'B00HBX7DD6': ['B01GWMFSYM'],
#  'B00K1HQWBS': ['B00KK9I08A', 'B00BNRJAW8'],
#  'B00I0ZF9VM': ['B00R6K0JM6', 'B00JH7933W'],
#  'B01DIF788U': ['B00JCA3F88', 'B01EPCXCU8', 'B00L2FQEVG'],
#  'B00TBTC3HO': ['B00OFA7YEQ', 'B019DFM1WM'],
#  'B00CMU1IN4': ['B00FPCJSYC', 'B00HMUUFJC'],
#  'B00AVKL9KO': ['B00DLATS18'],
#  'B00GCVZEG6': ['B00I1VXA3O', 'B00ZYX46P8'],
#  'B00CS74GE4': ['B003FL6X52', 'B00ED27A04', 'B00ND9FI3Y', 'B00GP3HP18'],
#  'B00NDD3L4I': ['B00GPDYL56', 'B00N5JBZ5C', 'B00C2L7N4G', 'B00P32ZUAK'],
#  'B00LD1ORIG': ['B004XW3LLQ'],
#  'B011JD9SYU': ['B00LXHHBNS', 'B01CT2VV90'],
#  'B00EEPZHI2': ['B00M27P9D2'],
#  'B010F3PVVY': ['B00FD7Z51O'],
#  'B00GNQWYOK': ['B00CCVVKMW', 'B00GK37PIG', 'B00A6ROZ12', 'B00BUAZL12'],
#  'B00DGFXDLO': ['B00563EYAS'],
#  'B00FRXNHVY': ['B00BW73VVU', 'B00ESPZ2C4', 'B00BEOYH0U', 'B00DVYIQDA'],
#  'B00JTCH5RQ': ['B00R04OX5C', 'B00G6N3IA4'],
#  'B01FGJ3754': ['B00LMTLV24', 'B00MUXSBBA', 'B00KHHOUKW', 'B00OGM2722'],
#  'B00CJJ2314': ['B00FP8QLTG', 'B00BV0IM9E'],
#  'B00A9Y49CM': ['B0173QJGLW', 'B01CF7VQVW', 'B00LYD3TZU'],
#  'B00JFHKEOG': ['B00HVJNAXC'],
#  'B00J0PKKUG': ['B00MQ5BIE4'],
#  'B00DHW4N6K': ['B00CWFAQJQ', 'B0082CA0Z8'],
#  'B00CLDQ8XW': ['B00R40ON3Y', 'B00QSAWMKC'],
#  'B00D6XE2GQ': ['B00BC6SSKU', 'B00C6NBTPE'],
#  'B00L2K4D0U': ['B00OYWP6G8'],
#  'B009H516LG': ['B005UJR9JQ', 'B00CU7FV6O', 'B008WHUQYS'],
#  'B00D7WKQRA': ['B00FJFV6AY'],
#  'B00K2BX8WY': ['B00HZ3RTM2'],
#  'B00O4GUH1S': ['B00ICTUW6I'],
#  'B00T6HTQTY': ['B00T3P4KRW'],
#  'B00JBGZKJK': ['B00EXFFVHA', 'B00H3M921G'],
#  'B00RO392V4': ['B00AFYBXEI', 'B00DXQ08QO', 'B01A164PSU'],
#  'B00G5IG3RK': ['B00HFYQ346', 'B00FE3R0GU'],
#  'B00HTAETEC': ['B005UJR9JQ', 'B00CU7FV6O', 'B008WHUQYS'],
#  'B00G15AKGC': ['B00G0TI2I2'],
#  'B0116LBLKE': ['B00ESV9MFG', 'B00TEPG4HK', 'B00ZY6REAY'],
#  'B00GU2DJBO': ['B00QH2FD98'],
#  'B00MQ5BIE4': ['B00J0PKKUG'],
#  'B013VDLXY4': ['B016PKYGGC', 'B0153XSCNA'],
#  'B00PVBEKQ8': ['B00H95FQRG', 'B00DWLBBNY'],
#  'B016YIRT9Q': ['B01FTEBE74'],
#  'B012U86IBY': ['B00PW1FVXI'],
#  'B01FCRUS84': ['B017JA1SFO'],
#  'B01AWS518A': ['B01CDF5PWW', 'B016YX01U0', 'B00JDN08SE'],
#  'B01D9JB7DW': ['B006JDEK0I'],
#  'B00DSB1M5U': ['B00H0FIZAU'],
#  'B00K9NWRHW': ['B00CK51JT4', 'B00FIL334Q'],
#  'B00VJ83PXG': ['B017O4W3V8', 'B00PUSKH14'],
#  'B00KEFZQ14': ['B00QVNQYIM'],
#  'B00AK4SWUQ': ['B00PPDJ7OW', 'B00CF6IY50'],
#  'B00XAGLZWS': ['B01B9XNJP4', 'B0103UGC1C'],
#  'B00LMTLV24': ['B00KHHOUKW', 'B00OGM2722', 'B00JIWJ78C', 'B00MUXSBBA'],
#  'B00Z7Z2A6A': ['B00NWR78L2', 'B00GEHN4I8'],
#  'B00EN3BMN4': ['B00KVQZSF0', 'B00M7ILTLW'],
#  'B00TP4X5CM': ['B005EH7GXS'],
#  'B01E8H55ZA': ['B00XM7VJMG', 'B00R4Y1MMK', 'B00KFZCAAI'],
#  'B00N00BM2M': ['B007Z4WSOK'],
#  'B00HP5A8FU': ['B00HY0GTYK', 'B00MWZXZKS', 'B00KVQZSF0', 'B00M7ILTLW'],
#  'B00OAJUEW6': ['B013GZOXPS'],
#  'B006QMPI62': ['B00BJCBPIO', 'B00Q1UTQ76'],
#  'B00SWAXORQ': ['B00SXNYCU0'],
#  'B00L2F5P02': ['B002SVQD0A'],
#  'B00DP8R3P4': ['B00GW60KC4', 'B00L0OKIT8'],
#  'B0097K1IAK': ['B00DP8R3P4', 'B00GW60KC4', 'B00FABMQ74'],
#  'B00BD2PT8M': ['B00G8UKDQ2', 'B00Q5OG0RM'],
#  'B01BHE3H1G': ['B00MQCND7W', 'B00OEOF882'],
#  'B00KLILI5M': ['B00JM2HG18',
#   'B00OJG202W',
#   'B00L2FG1Y6',
#   'B00N27UEPE',
#   'B00KZ6LWWO',
#   'B00MJPJ56O',
#   'B00K7UH84O',
#   'B00O5OLJ0C'],
#  'B00DJK31TK': ['B00Q79E1AI'],
#  'B00BFQDDZ2': ['B007YIZ2YA'],
#  'B00CGFGS3A': ['B009D628ES', 'B006JDEK0I'],
#  'B00HJZF38S': ['B00CH3NV4U'],
#  'B00EJXIO7U': ['B00FVDMDOC', 'B00IU087O8'],
#  'B018PPWK0E': ['B00S0IR6T2', 'B018IYY2V2', 'B00TSJGAD0'],
#  'B00L8A3BMK': ['B00K6S71RG'],
#  'B00JK54EFS': ['B00IGVA8SE', 'B00KQ4FVLS'],
#  'B00JORD84K': ['B00HY2KN04', 'B00HVRDDQ8'],
#  'B0098AUF7G': ['B0091USXFO', 'B0165WFX2Q', 'B00BTRSOJ2'],
#  'B00MIA63WE': ['B00NIDWKB8', 'B00HP90OBE', 'B00RAVZRVE'],
#  'B00LNJ4ABC': ['B00M7E63YO'],
#  'B00UW0GTSK': ['B00BHLGZJ6',
#   'B00KJICKNI',
#   'B00IOU3ZCI',
#   'B0091M6ERQ',
#   'B00D4ITQCS'],
#  'B00ARXXW50': ['B00U7O4IQ6', 'B006MLKZWO'],
#  'B00T22Y062': ['B00ZRYDR86', 'B00TEPXICO', 'B01097AOJA', 'B00T94ANNM'],
#  'B00DH16D2I': ['B00L01GJAS', 'B00L8BMUZS'],
#  'B00DTIBSMY': ['B00W22ITCU', 'B00CKH0ZDS', 'B00CHP64IS', 'B00NHDEB34'],
#  'B00PJKXZGC': ['B00KSNA2R0',
#   'B00U9U223Y',
#   'B00A946MNQ',
#   'B00JWVVXEU',
#   'B00EMG3A00',
#   'B00L2X37QS'],
#  'B00KFMRU5Q': ['B00OX60XLS', 'B00JZWDC9K'],
#  'B005SZ171I': ['B00LH8I7PE'],
#  'B018F6H3U0': ['B00K1OAXKM'],
#  'B010TYBN4S': ['B0130LQWBG', 'B00WVOSY8S', 'B017XVQCZU', 'B015424GP8'],
#  'B00EDDC0NK': ['B00CSEHXQU'],
#  'B00QZF4D70': ['B00WRNKOOU'],
#  'B00DE3MJ8G': ['B00FL3VPD2'],
#  'B00HK4EGY0': ['B00IZL6KTG', 'B00MR282E0', 'B00O8CFKKG', 'B012LB9KDI'],
#  'B00E5UJAIO': ['B00K31DCD8', 'B00HNWEA9K', 'B00JTCDAPC', 'B00M3GWXHW'],
#  'B00D5M4PTM': ['B00QU06V2K'],
#  'B00UO7WUBG': ['B00P8FU8UY'],
#  'B00IDHIGBM': ['B00MXL10A8', 'B00KGKCIQI'],
#  'B00SW2TWJS': ['B019OYETT0'],
#  'B00HT73RHK': ['B00QL0I6B8', 'B00K0N2SRA', 'B00OCZDME0', 'B00GB36DDI'],
#  'B00JRJXGWO': ['B00PISYDD4', 'B00QLA3DKC', 'B00MJ2232K'],
#  'B016SIV5SS': ['B00J6GU2AC', 'B00TSXRDW8'],
#  'B00PBA6QCU': ['B014I8OGLS'],
#  'B018PU8DK0': ['B00GF64L5S', 'B00BXGUOU6', 'B00LZ5SRTK'],
#  'B0172LVWUQ': ['B0104EOJMQ', 'B00JTCH5RQ'],
#  'B00MQ999AK': ['B00JBSTU0I', 'B007CIMWZO', 'B00I15JCPK'],
#  'B016SLVJD6': ['B00L2FQEVG', 'B01ATZTMH2', 'B00JCA3F88', 'B00VE5O30I'],
#  'B00E5PJOYY': ['B00DOJ93PC', 'B00E5JAIP4', 'B00GY34GUM', 'B00HHGRE22'],
#  'B015GEUFCW': ['B016FIYXEE', 'B017S1KRCO'],
#  'B00BJCBPIO': ['B0081H2KH0'],
#  'B00OYWP438': ['B00F2TFH5W', 'B00ENVYVHA', 'B00CCVVKMW'],
#  'B005UJR9JQ': ['B00HTAETEC', 'B009H516LG', 'B00CU7FV6O'],
#  'B005ZWRMM2': ['B00537SQME', 'B00HGW82TG'],
#  'B004KKY782': ['B005LC1NGW', 'B004IPPKNU'],
#  'B00ZO50HZO': ['B00AABHU70', 'B013OHD20A', 'B00DH7XDKM'],
#  'B00QE466KY': ['B00N8G9PFO', 'B00K31DCD8'],
#  'B00G6BLT1Q': ['B006LTB8BE', 'B0068UAZ8I'],
#  'B00MMV5WAI': ['B00UY3LLY2', 'B0090P1MIU'],
#  'B00L0OKIT8': ['B00NLZ02Z4', 'B00DP8R3P4', 'B00GW60KC4'],
#  'B0083868PM': ['B008YJLDY6',
#   'B00QI8BV9W',
#   'B01ETKZY0W',
#   'B00KSND3LW',
#   'B00Y9H7M0G'],
#  'B0051AH20A': ['B006N09CCS', 'B006GZ1VU6'],
#  'B00MZI379Q': ['B00JNK590Y', 'B00JNELJPY', 'B00KBN0F3S'],
#  'B00JNK590Y': ['B00JNELJPY', 'B00MZI379Q', 'B00KBN0F3S'],
#  'B00JK1ZABE': ['B00ESV9MFG', 'B00V50VSUU', 'B00OO7Y1EG'],
#  'B00V8CETHO': ['B00UKKMKD0'],
#  'B00TEPYFQM': ['B00ZRYDR86', 'B00TEPXICO', 'B01097AOJA', 'B00T94ANNM'],
#  'B012OS8WBE': ['B0110IXWIM',
#   'B00UY3LLY2',
#   'B00YO2UO9M',
#   'B00VR8I1C8',
#   'B00NTPCN76'],
#  'B00T2TSFH0': ['B010TZVSTM', 'B019OYETT0', 'B00IRNT56M'],
#  'B00Q5OG0RM': ['B00G8UKDQ2'],
#  'B00UI5G3CQ': ['B00IX2YORW', 'B00UI5GKQA', 'B00AOG8I3Q'],
#  'B003Z9K8A0': ['B00A2WZ1IC', 'B003VD1EAI'],
#  'B00HI56L8U': ['B013UBALKE'],
#  'B00HY3HN7E': ['B00IJFYICO', 'B00CJV6N0Y'],
#  'B00MT0UR3Y': ['B00E9LXPIU', 'B00F70LNO0'],
#  'B00CVS2KH0': ['B00TEU4CQU', 'B00PMOM70U', 'B00BSW7PU2'],
#  'B00C53PC7Q': ['B00CDVZFRW'],
#  'B00CCH4WKI': ['B00BANV988', 'B0068XJXJC', 'B00E37365C'],
#  'B019VTO2P4': ['B00JAQX4HQ', 'B00N2AHDHI', 'B00QXWYEYW'],
#  'B00BD63EIK': ['B00DH8T4DG', 'B00CJ1ICH6'],
#  'B00HTQ5E22': ['B00VCM31QK', 'B00NK0MK8C', 'B008X5D132', 'B00M3GWXHW'],
#  'B00BLOI13C': ['B00UY3LLY2', 'B00I7BC9A8', 'B0058OJ8AG'],
#  'B0116SLML0': ['B015L2UR1S', 'B00TEB4HAU'],
#  'B011IXZ6KQ': ['B017OGHBT0', 'B00D2Y3BFC'],
#  'B00O0CY3LQ': ['B00HB62M3E', 'B00G0ZMWOG', 'B00GEEB15Y', 'B00AYIDVLS'],
#  'B00R1O4KWW': ['B00J9YWGTQ'],
#  'B00YSW6NWU': ['B00MK395WO',
#   'B00S0IR6T2',
#   'B00X4112W2',
#   'B01E0DMKMI',
#   'B01CD4OVX2'],
#  'B018BDHGS6': ['B00BFQDEBU', 'B00ZJ5YDW2'],
#  'B00NVMJ03C': ['B00MRFP7E0'],
#  'B00FBMKRG4': ['B00N5TWLH8'],
#  'B00J5327X6': ['B00JUV8JPS', 'B00L83QEHG', 'B00INYO7MC'],
#  'B00A64ETZW': ['B00DX5DHQS', 'B00903I7U8', 'B00H5UAEZY', 'B0121F21ZS'],
#  'B018A097LO': ['B00TFX0HYC', 'B00V9525BC', 'B00JJ7LFMM'],
#  'B00DMR0NTQ': ['B00H3HRWDQ'],
#  'B006IJUOS0': ['B006N09CCS', 'B006GZ1VU6', 'B005MZ8SE8'],
#  'B00CS7EAHM': ['B00ADEJ8WY', 'B00NK0MK8C', 'B00KPHRED4'],
#  'B00NW2BZD4': ['B00ICTUW6I', 'B00O4GUH1S'],
#  'B00WOQBPOI': ['B006PVGZ0W', 'B00F3G29QY', 'B007YUYWPS'],
#  'B00JFGHXPU': ['B00KPF2M6U', 'B00IJCB3M0'],
#  'B0057G5BQ0': ['B00NK0MK8C'],
#  'B00HBIZ4UA': ['B00FRXNHVY',
#   'B00BEOYH0U',
#   'B00DVYIQDA',
#   'B00BW73VVU',
#   'B00ESPZ2C4'],
#  'B00KJICKNI': ['B00UW0GTSK', 'B00BHLGZJ6', 'B00D4ITQCS', 'B00IOU3ZCI'],
#  'B00MD4TX68': ['B00LUC227G', 'B00O27QJIE', 'B00N00N4UK', 'B00JJY2XX0'],
#  'B00H3I2172': ['B015RPT6XY', 'B00P9RU6SK'],
#  'B00CNTSVZM': ['B00BW73VVU', 'B00G0J9CGS', 'B00FRXNHVY', 'B009UVK28U'],
#  'B00TIUEVL2': ['B00TEEHDPS', 'B010W9HEUW'],
#  'B00DHWLPWK': ['B00KCX47VI', 'B00HFUAODQ', 'B00GWPCIL6', 'B00MQ2NCY6'],
#  'B00HSCB6KQ': ['B00XUR39GC', 'B00MO3GPFU'],
#  'B017KUZUM0': ['B00U0F0VGI', 'B019DFM1WM', 'B00QNZGJVA', 'B01757MBGG'],
#  'B01D3H7LYO': ['B00RCEN9J6', 'B00LUC227G', 'B00O27QJIE'],
#  'B005TLKZR8': ['B01B6WT11Y', 'B00NZLNUXA'],
#  'B00YQD91RA': ['B00CLZCRIU', 'B00FHFODOM'],
#  'B00C8X8Q5S': ['B00ID2A1PQ'],
#  'B00LFW9MQK': ['B00HY0GTYK', 'B00MWZXZKS', 'B00KVQZSF0', 'B00M7ILTLW'],
#  'B00JZWDC9K': ['B00OX60XLS', 'B00KFMRU5Q'],
#  'B0104OFHEK': ['B00SPA1Z5Q'],
#  'B00R20MQW6': ['B00QU3MMZM', 'B00AIDLZFI'],
#  'B00VX75TKU': ['B01CMK63A6'],
#  'B00F2ZL3W2': ['B00IHMEBR6', 'B00BQMOGKQ', 'B00BMU2VEK'],
#  'B007JNP67S': ['B00IX3QJO2',
#   'B00M122F7Q',
#   'B00MQ2NCY6',
#   'B00JMRE4L8',
#   'B00KCX47VI',
#   'B00GWPCIL6'],
#  'B00KYC5SY2': ['B00A946MNQ', 'B00L2X37QS', 'B00L0LQCQ4'],
#  'B00DK7EGCI': ['B00PQV6H78',
#   'B00NGOXQOY',
#   'B019AJC8DS',
#   'B00LD6IYUI',
#   'B00GU460T0'],
#  'B005S1XTEA': ['B00H2ZK6FU', 'B00N05R8GG'],
#  'B00YAKL5A0': ['B0182RBPSI', 'B00HUXNM6O', 'B00AK2UISW'],
#  'B00YV666B6': ['B00BK50QYY', 'B01E6DT75U'],
#  'B0196TRK8K': ['B00WZSQ734', 'B015Y80IGS', 'B012TE6QVG'],
#  'B00C8VW0JS': ['B00F4BWD46', 'B00B3NX16I', 'B00ZZNF0TS', 'B004HO5ZY6'],
#  'B00BFWI9BY': ['B00IJFYICO', 'B00DVWRDN6', 'B00EEE52DI', 'B00CJV6N0Y'],
#  'B00E83TA4C': ['B00GRAZD3G', 'B00ET55NGS'],
#  'B00OMG2XSK': ['B00ASP8XNS', 'B00QJKV1EY'],
#  'B015UN87JC': ['B00ZOL1DRO', 'B00FL1HYCA', 'B01D6OUQS2'],
#  'B018QV5KW2': ['B00I52PPT6', 'B016QIBZC6', 'B00NH2QTC6'],
#  'B00YLNSKTA': ['B00JYJTBUI', 'B00GXF9BRO', 'B00838H1OY'],
#  'B00MTACJ8A': ['B00RN81ERU', 'B00MU3PU5K', 'B00NTRYYT4'],
#  'B0073SJELI': ['B009A21KSK', 'B007PW331E'],
#  'B0117VIQRE': ['B00S776ER6',
#   'B00RXZXOWQ',
#   'B00ZTMRHQ4',
#   'B00T0WXD8K',
#   'B00U89TGNU',
#   'B00RYC3A3Q',
#   'B00VH4UFMG'],
#  'B00HCK1TZQ': ['B00PBVRFUQ', 'B00JO4GO94'],
#  'B00R298H3O': ['B00NK0MK8C', 'B00QE466KY'],
#  'B015IF44GW': ['B006PVGZ0W', 'B00F3G29QY', 'B007YUYWPS'],
#  'B00HG5JL34': ['B00PNU8Z86', 'B00JWTGGVC'],
#  'B00L5Q7EB6': ['B00JAQX4HQ', 'B00QXWYEYW'],
#  'B00H8XIAZ4': ['B017S1KQ0M',
#   'B009B56MFW',
#   'B00MBQASGC',
#   'B00TQ70PMG',
#   'B00RULF80E'],
#  'B014Q6D6E0': ['B013VDLXY4'],
#  'B01CT4MKIE': ['B01A6OP92S', 'B01A03HKFE'],
#  'B019169ROS': ['B00CPV1INK', 'B004W9BX7Y'],
#  'B00XV3MUAG': ['B00T7XXV3Y',
#   'B014T6L87E',
#   'B00U48LDN6',
#   'B014GCDQ62',
#   'B00TU7C7K0',
#   'B01297KYDO'],
#  'B00ET7Q4OG': ['B00CSBQ5YO', 'B00FQQ1A8Y'],
#  'B006KDUPH4': ['B00C7HG9KY'],
#  'B00W0EETII': ['B0130LQWBG', 'B015424GP8', 'B017XVQCZU'],
#  'B00AXLV0CI': ['B00D0VMCXO'],
#  'B00KVP3042': ['B00P6HT5GM'],
#  'B00NYB481E': ['B00U2521PU'],
#  'B00BQMOGKQ': ['B00IHMEBR6', 'B00F2ZL3W2', 'B015YEH900'],
#  'B00B3DROPW': ['B00I48KN16', 'B00P46P3XY', 'B00HH1JVCI'],
#  'B00LD69NIA': ['B00C11XQLG', 'B005Y2MYNK', 'B010JA571W'],
#  'B00H8Q5AGI': ['B00FAYYWNC'],
#  'B00YOAZYYY': ['B00FKERXXS', 'B00C5R83E6', 'B00Q5DLY42', 'B00TJ3G4U4'],
#  'B00EH2N8RO': ['B00GAPQ4FO'],
#  'B00D1F1DNY': ['B00BZY9P0Q', 'B00P7XAQ22'],
#  'B00H0GED9Q': ['B00GBIYX8A', 'B00ECBS5OQ'],
#  'B00HFUAODQ': ['B00BY5XSIG', 'B00JCYNMUU'],
#  'B00E9F6X5S': ['B00957XZFG'],
#  'B00VH5NX4C': ['B00K0LAH3Y'],
#  'B00HMP4JEO': ['B00A946MNQ', 'B00L2X37QS'],
#  'B00CAW3G66': ['B00CIAD6UQ',
#   'B00UY3LLY2',
#   'B006M6XV1Q',
#   'B00EECLODW',
#   'B006RZNR3Y',
#   'B00GJBUZ7W'],
#  'B008X5D132': ['B00NK0MK8C', 'B00HTQ5E22', 'B00M3GWXHW'],
#  'B01B9XNJP4': ['B0103UGC1C'],
#  'B00I8Y3OI0': ['B00JYJTBUI', 'B00GXF9BRO', 'B00YLNSKTA', 'B00SNRG8I0'],
#  'B00QNYKI7C': ['B00DU2IYVM',
#   'B00QI8BV9W',
#   'B00KDKCMKI',
#   'B00AB1ZGX4',
#   'B01AAXMLVW'],
#  'B00OO4LIS6': ['B00ENVYVHA', 'B00PMK53SW', 'B00CCRTFSC'],
#  'B00CFOJU3C': ['B009XIQVWQ',
#   'B00DE50M2E',
#   'B00EYJ2LGY',
#   'B00OD0O94G',
#   'B00PF1A0PY'],
#  'B00S5J5ZG2': ['B00FY54JYO', 'B01HDNEFGQ', 'B013Q700KS'],
#  'B00OQEBXUM': ['B00GWPCIL6', 'B00M122F7Q'],
#  'B00N1BXC8C': ['B0165SOAPG', 'B00QQOX6LY'],
#  'B00LK4SUCU': ['B00BT1T1ZY'],
#  'B00KZKZTNI': ['B00S6ROWI0'],
#  'B00D2R5QB6': ['B00K56DJ16', 'B00PNP8Z8Q', 'B00NLMSYIE'],
#  'B00JLHHYWA': ['B00HP3RUWQ', 'B00NJ4BB84'],
#  'B00OKM7SVI': ['B00DB7RV60', 'B00C5W86XE', 'B016HIOV08', 'B00E9GQQ9K'],
#  'B00ARFOGQ2': ['B00CO6DD4I'],
#  'B00H1VKZL0': ['B00DVYIQDA'],
#  'B00KK1GLWA': ['B00LS6MCMY', 'B00JDLFHRI'],
#  'B00JBSTU0I': ['B00I15JCPK', 'B007CIMWZO', 'B00MQ999AK'],
#  'B01069Z6TO': ['B00OO4LIS6', 'B00PMK53SW', 'B00YN6XHMU'],
#  'B0143PGMCC': ['B00U9U223Y'],
#  'B00R04OXC0': ['B00R04OX5C', 'B00MZWA6KA'],
#  'B00HH1JVCI': ['B00I48KN16', 'B00P46P3XY', 'B00LXNM46G'],
#  'B00L0Y84QC': ['B00D048R6W', 'B00AMUZS3W', 'B00EB323E8', 'B00AV4X6GK'],
#  'B00CRFHJAA': ['B00F50R0H6'],
#  'B00JNU6GLK': ['B00M8QQMC4', 'B00L2V73GK'],
#  'B00N52516S': ['B00K4C45PA'],
#  'B00I7BC9A8': ['B00QU63A9Q', 'B00JCYNMUU', 'B0058OJ8AG'],
#  'B00EYJ2LGY': ['B009XIQVWQ',
#   'B00DE50M2E',
#   'B00OD0O94G',
#   'B00PF1A0PY',
#   'B00CFOJU3C'],
#  'B00AKCVNX6': ['B00HJCPDVI', 'B005CX33HM', 'B005CWJJO4', 'B005C5YZ86'],
#  'B00A1ENUM0': ['B00AKOIUG2'],
#  'B00UB8UK42': ['B00Y1YQBZ4', 'B00VC2I61A', 'B00SKFEE1S'],
#  'B015BH04E8': ['B019VJ697I', 'B00RY2IAMM'],
#  'B00HBWQCAC': ['B006MIN0RE', 'B00GVB3NQA'],
#  'B0089EI560': ['B01A1E8WO0', 'B00732PC0Q', 'B01C4MED1S'],
#  'B00KBN0F3S': ['B00JNK590Y', 'B00JNELJPY', 'B00MZI379Q'],
#  'B00FO60CH6': ['B00DH8T4DG', 'B00NLHJI70', 'B00BD63EIK', 'B00BMU2VEK'],
#  'B01CT2VV90': ['B011JD9SYU'],
#  'B015424GP8': ['B0130LQWBG', 'B00W0EETII', 'B017XVQCZU'],
#  'B01A5CT9X6': ['B01D8VMKJ6', 'B01CBXUNJ6'],
#  'B00OYBCSVU': ['B00UJOUELW'],
#  'B00CNVVJ68': ['B00FD7Z51O', 'B00CD7QO5S'],
#  'B00HG1T1Z6': ['B00OO65H90'],
#  'B00RHH7LLU': ['B00QI8BV9W', 'B00LJ23SEI', 'B00LNMM6SI'],
#  'B00C7AED9A': ['B00EHSUFD8',
#   'B00QI8BV9W',
#   'B00CFAGTV2',
#   'B00BNZDOFE',
#   'B00C7Y0T8A',
#   'B006ITXEVO'],
#  'B0113MEPOA': ['B01F1JLPH6'],
#  'B00HLQWVMQ': ['B007Z4WSOK'],
#  'B00O7WX2WA': ['B005O54AOI', 'B00GVZZQ2A', 'B00SWF7O7M', 'B01C8CLGR8'],
#  'B00HZ5ZDX2': ['B00D3R66N2'],
#  'B004AYDJM8': ['B00YN6XHMU'],
#  'B00B2F3W0W': ['B00GEHN4I8'],
#  'B00E40F64M': ['B00T3E76II'],
#  'B00EPPVJM4': ['B00MQ20P28'],
#  'B00ALTVIJM': ['B00C45BQT8', 'B007E2O6IE', 'B011M0SQ48'],
#  'B00C45BQT8': ['B007E2O6IE', 'B011M0SQ48'],
#  'B00QE2ASI2': ['B00IX0MNPY', 'B00JCA3F88', 'B00L2FQEVG', 'B00IX5FCR0'],
#  'B005OC5QXK': ['B0085MBTVO'],
#  'B00E6ZZ4DS': ['B00FURCF9C'],
#  'B00QW6JBME': ['B00NN5ZPOA'],
#  'B0058EU1Z2': ['B00BMU99HM', 'B00YN6XHMU'],
#  'B00PMRE1BA': ['B00W891R26', 'B00HNKVDOW', 'B00LS610HC'],
#  'B00GF5XK0Q': ['B00D4ITQCS'],
#  'B00VISSZOQ': ['B0177475MW'],
#  'B00RMB80SO': ['B00U0F0VGI',
#   'B00ZYAZFC4',
#   'B0145COWD4',
#   'B019DFM1WM',
#   'B00HG4NPVE',
#   'B01757MBGG'],
#  'B00DKAQ9JS': ['B0195SIAG8', 'B00BSX46G2', 'B00NZLNUXA', 'B00F077J3O'],
#  'B005CQBCJA': ['B00LNJ4ABC',
#   'B00CT1TMG6',
#   'B0095JRPM8',
#   'B0095JRP0K',
#   'B005MTB73S'],
#  'B00CPG1UII': ['B00C4BA44K', 'B00JDYCHM8', 'B00KH3Z53W'],
#  'B01FIJL2EA': ['B0070CSKE4', 'B019LOFJE2', 'B008HH98A6', 'B00QJ4TCN2'],
#  'B00SW8HQSQ': ['B015HN8TSY', 'B00RSQSZVU'],
#  'B00DZSOC62': ['B00XPKE8GY', 'B00W4LYJ6Y'],
#  'B00KMB9SG4': ['B00PSEO3XS', 'B00OBRHV3M', 'B0147H31BG'],
#  'B009YLKRAO': ['B00P1FOLPY',
#   'B00GK50H66',
#   'B00IOXWK2G',
#   'B00JJ7LFMM',
#   'B00CG69E0I'],
#  'B011T78JT6': ['B010ZFRUQQ', 'B00DP8R3P4', 'B00L0OKIT8'],
#  'B010WM3TG2': ['B017KRJP7Y', 'B00QZABE5O', 'B01AJ6SEOS'],
#  'B00BGY7XX6': ['B0090W7ZB6',
#   'B00C2L7N4G',
#   'B00P32ZUAK',
#   'B0069FJE4S',
#   'B005LVV6DI'],
#  'B01CXRI0W2': ['B013FRIR0O', 'B00NAI85T2', 'B01B3LJZAA'],
#  'B00I52PPT6': ['B00MY6POOK'],
#  'B00MCT40XU': ['B007Z4WTBW', 'B00FTP60FU'],
#  'B00TWOW2GK': ['B015C8H12E', 'B00LXK4KIO', 'B00ILKTBSI'],
#  'B00V9525BC': ['B00TFX0HYC', 'B018A097LO', 'B00JJ7LFMM'],
#  'B01BA7DLWA': ['B00JS6Q8E4', 'B00Q4YAJL6', 'B00PHV4KM6', 'B00IKKZTPI'],
#  'B00CSEHXQU': ['B00EDDC0NK'],
#  'B00H0OKQ76': ['B00AVKKUKE', 'B00EN6LQYQ'],
#  'B005CCM48M': ['B005UGMC78'],
#  'B01AQ5B1UG': ['B00TGC71K0'],
#  'B00N27UEPE': ['B00JM2HG18',
#   'B00OJG202W',
#   'B00L2FG1Y6',
#   'B00KZ6LWWO',
#   'B00MJPJ56O',
#   'B00K7UH84O',
#   'B00O5OLJ0C'],
#  'B00EH2E5IK': ['B00DLSTT9Q',
#   'B00W3QA7VG',
#   'B014Z40CGI',
#   'B015VKB8KY',
#   'B00CS98VC0'],
#  'B00KVT8U4S': ['B00LD6IYUS'],
#  'B00M9P6LGG': ['B00EOKKVG0', 'B00FIWMEU4', 'B00H3LM7UA', 'B00BYLQUGM'],
#  'B00R8EKHVS': ['B00AV4X9TO'],
#  'B00BVXQS1U': ['B005GFILNW', 'B00CEHVUKQ', 'B00COMUGY2'],
#  'B00HWKW7K2': ['B00QIQNWXW', 'B00N99OHZS', 'B00BUCJV70'],
#  'B0149IDQV8': ['B00SXNYCU0', 'B00Y9H7M0G'],
#  'B00N9IMHCE': ['B00N99OHZS'],
#  'B00R1PTSLY': ['B00GPDYL56',
#   'B005DPIINI',
#   'B00C2L7N4G',
#   'B00P32ZUAK',
#   'B00S5NS39Y',
#   'B00N5JBZ5C'],
#  'B010BDZ9MY': ['B0117VIQRE',
#   'B00S776ER6',
#   'B00RXZXOWQ',
#   'B00ZTMRHQ4',
#   'B00T0WXD8K',
#   'B00U89TGNU',
#   'B00RYC3A3Q',
#   'B00VH4UFMG'],
#  'B00Q9QAF9A': ['B00NLLP3MU', 'B01DJZ7G5E'],
#  'B018WYKTR4': ['B00XNLIPOG'],
#  'B00EXW70LS': ['B00MTACJ8A', 'B00HGTI24Y', 'B00MU3PU5K', 'B00NTRYYT4'],
#  'B019E9VZG0': ['B01GF9OQSQ', 'B01GBW546U', 'B00PMH3R3I'],
#  'B01GP9AIAQ': ['B00ZZNF0TS', 'B009IAMZGU'],
#  'B00B0645XG': ['B00MRM8394', 'B00DNCONGE', 'B01H173WKO', 'B0080SA5S6'],
#  'B00H3HRWDQ': ['B00HV5RCI0'],
#  'B010JA571W': ['B00C11XQLG', 'B005Y2MYNK', 'B00LD69NIA'],
#  'B00ENVYVHA': ['B00CCRTFSC'],
#  'B01DRBV052': ['B00NDEXI0O', 'B00LK4SUCU', 'B01HFTVMXM'],
#  'B00TVT5KD8': ['B00V3PSE0Y', 'B00XFS22CS', 'B00YO52DW0', 'B00UGP39S4'],
#  'B0157E64K8': ['B00ZYAZFC4', 'B019DFM1WM', 'B01757MBGG'],
#  'B00CU7FV6O': ['B006CC6ZTU', 'B005UJR9JQ', 'B00E7KTERY', 'B00BV0A5SK'],
#  'B00HGW82TG': ['B00JFGHXPU'],
#  'B00KEZK9F2': ['B00R3ABBVC', 'B00B687AX0'],
#  'B007YU6EVI': ['B00GQQPU4I',
#   'B00PXGD274',
#   'B004UGMVP2',
#   'B00AYR3BS2',
#   'B00ZKB2732',
#   'B0095KJ9R6',
#   'B00VCM31QK'],
#  'B00D4ITQCS': ['B00GF5XK0Q'],
#  'B00H3QI9BQ': ['B005GMUU8O', 'B00EAHZR5W'],
#  'B008V1UB86': ['B00EI5XX7U', 'B00758KQ22', 'B00HQSEA96', 'B01FVHS6OI'],
#  'B00VQJHHRI': ['B00VQJ0GTE'],
#  'B01G9GUS14': ['B00JD28AJ4'],
#  'B00U4CW5W0': ['B016OR83AG', 'B00DE33QPQ', 'B01BA27G4E', 'B00UY3LLY2'],
#  'B00LDTQ2ZY': ['B00NNEIL0Q', 'B00LS7LA7G', 'B011LZ02Q4', 'B00OWN9QQU'],
#  'B00K4C45PA': ['B00N52516S'],
#  'B00MXS70SW': ['B00HV3XL2I', 'B00N9AOG12'],
#  'B007XYIGR0': ['B00HE4Z51Y',
#   'B00P32ZUAK',
#   'B00AJUVJN8',
#   'B009BZFQ4U',
#   'B00N5JBZ5C'],
#  'B00KWEXNN0': ['B00CSBQ5YO', 'B00IRLFH9S', 'B00RRLU0PK'],
#  'B00GUZ195O': ['B00GEHN8ZW'],
#  'B00LXK4KIO': ['B00TWOW2GK', 'B015C8H12E', 'B00ILKTBSI'],
#  'B00UVLQOBC': ['B01AB4CLHY', 'B010MPIOWI', 'B0145VI0G0'],
#  'B010MPIOWI': ['B01AB4CLHY', 'B00UVLQOBC'],
#  'B00I1WAG44': ['B00L1R3OS6', 'B00CQYAVRK'],
#  'B00HGSV6I4': ['B00L2X37QS', 'B00A946MNQ', 'B00FFH1QEW', 'B00L0LQCQ4'],
#  'B00KVOCLXE': ['B00IOSBC3Y', 'B00GVQOJZ4'],
#  'B00VSUD134': ['B00LYMVPXE', 'B01609PRNY'],
#  'B018F3C1KU': ['B00VPMQTKW', 'B00KLO64S2', 'B00Q6Q5ZP2'],
#  'B00957XZFG': ['B00E9F6X5S'],
#  'B00HFYQ346': ['B00FE3R0GU'],
#  'B00ZY6REAY': ['B00ESV9MFG', 'B0116LBLKE', 'B00TEPG4HK'],
#  'B00AOG8I3Q': ['B00UI5G3CQ', 'B00IX2YORW', 'B00UI5GKQA'],
#  'B016HFRV3A': ['B00U9U223Y', 'B00ZJ5YDW2', 'B00Q1UTQ76'],
#  'B0070J2HD2': ['B00HM6Y632'],
#  'B00IYUI8AW': ['B00M9VZ72E',
#   'B00L0LQCQ4',
#   'B00NRWI91U',
#   'B00A946MNQ',
#   'B00L2X37QS'],
#  'B01FIS2F42': ['B013AOYW4C'],
#  'B00DCBMEQW': ['B00ESPZ2C4', 'B017ACSD1S', 'B00KXM8IP4', 'B00DVYIQDA'],
#  'B00KGC2SV6': ['B00CFAGTV2', 'B00K61S5VO', 'B00IFTK8CS', 'B00GI9969I'],
#  'B00IMNWM3K': ['B00CMY7028'],
#  'B01AWPTL0W': ['B00OQY2X06', 'B017DGXD0M', 'B014JSBJJ4', 'B01GCULNK2'],
#  'B01DUO8QXU': ['B01DYXP2LQ'],
#  'B00UE3T6AI': ['B00JCELEZ0', 'B00AR5H52E'],
#  'B00S776ER6': ['B0117VIQRE',
#   'B00RXZXOWQ',
#   'B00ZTMRHQ4',
#   'B00T0WXD8K',
#   'B00U89TGNU',
#   'B00RYC3A3Q',
#   'B00VH4UFMG'],
#  'B00480P5TE': ['B00BIVE59M', 'B00DH7XDKM', 'B007LS0JQE'],
#  'B00R4ZHYXK': ['B00NN92YPY', 'B00D53OFPA', 'B00O55GSW0'],
#  'B00K395P12': ['B00F50R0H6', 'B00CRFHJAA'],
#  'B00AWHG6E0': ['B00LI5X2QA'],
#  'B0064P9O34': ['B005FIRJTC',
#   'B005DPIINI',
#   'B004UGMVP2',
#   'B00P32ZUAK',
#   'B00AJUVJN8',
#   'B005LVV6DI',
#   'B006OGOVM2',
#   'B005110E0O'],
#  'B00QSMLQIE': ['B018CLWDBM', 'B00CV6ZYLQ', 'B015NGF096'],
#  'B00OJFOI1O': ['B00NC0LECI'],
#  'B01620Y4O4': ['B00MQ20P28'],
#  'B00CMY7028': ['B00IMNWM3K'],
#  'B00DWLBBNY': ['B00JV0YWC2', 'B006DTZ0KC'],
#  'B00LS61SL0': ['B00DGFXDLO', 'B00563EYAS'],
#  'B00KSFTUAI': ['B017T8WJO0', 'B00M9RNZ7C'],
#  'B00JF7ZF90': ['B00O3GPDKO', 'B00MQDVWL0', 'B00KNGAX0I'],
#  'B00GG16KI8': ['B00F9B09WY', 'B00N12ERCG', 'B01CT5K792', 'B00PYOE24C'],
#  'B00FVDMDOC': ['B00EJXIO7U', 'B00IU087O8'],
#  'B01D8VMKJ6': ['B01A5CT9X6', 'B01CBXUNJ6'],
#  'B00EEIGHDI': ['B00FA2B9S0', 'B00BJCBPIO'],
#  'B006CC6ZTU': ['B00GVMSFQM', 'B00E7KTERY', 'B00BV0A5SK'],
#  'B01DN1BLKK': ['B01BTHWXF2', 'B01CDZAQTY', 'B01GPEDC3G', 'B01E4AF6VO'],
#  'B00KSNA2R0': ['B016ZG19KM', 'B00JWVVXEU', 'B00GVZZQ2A'],
#  'B00SPA1Z5Q': ['B00TCSWFX6'],
#  'B00LH773IM': ['B00K9O53UO', 'B00HTJJST4'],
#  'B00FPCJSYC': ['B00HMUUFJC', 'B00CMU1IN4'],
#  'B00OV9EXLS': ['B00KVQZSF0', 'B005L35E3O'],
#  'B0073XIROS': ['B00IZODKWS'],
#  'B0095KJ9R6': ['B00UY3LLY2',
#   'B00A45EANO',
#   'B00PXGD274',
#   'B004UGMVP2',
#   'B00AYR3BS2',
#   'B00ZKB2732',
#   'B00LJAZ7W6',
#   'B007YU6EVI'],
#  'B00LBBM60Y': ['B00MZCQERE', 'B00OSAVSDG', 'B00WZSQ734', 'B0196TRK8K'],
#  'B00MVE4X92': ['B00D8T3L5G', 'B00FIWMEU4'],
#  'B00FXBTYOO': ['B00FDX59UA'],
#  'B00U48LDN6': ['B00T7XXV3Y',
#   'B014T6L87E',
#   'B014GCDQ62',
#   'B00TU7C7K0',
#   'B01297KYDO'],
#  'B004W8D9V8': ['B0054H1I7S', 'B009FN1DA4'],
#  'B00TSJGAD0': ['B00S0IR6T2', 'B018PPWK0E', 'B018IYY2V2'],
#  'B00T3P4KRW': ['B00T6HTQTY'],
#  'B00C5IH1NO': ['B00BW73VVU', 'B00P9QXW1E', 'B00FRXNHVY'],
#  'B00OO7Y1EG': ['B00V50VSUU', 'B00JK1ZABE', 'B00JCYNMUU'],
#  'B00N6PD6OI': ['B00JQUC9OA',
#   'B00TCI48WC',
#   'B00OEXM6UG',
#   'B00C4BA44K',
#   'B00EMXC022'],
#  'B00BD1Q0IQ': ['B00JDSJWCM', 'B00E9N6WOM', 'B00N7SQJPW'],
#  'B00Q6Q5ZP2': ['B00KLO64S2'],
#  'B00YDI7CHO': ['B00T8E3V0A', 'B013NXMMLU'],
#  'B00C2E18A8': ['B00Z318GNY', 'B014Q6D6E0'],
#  'B00CGEZDOQ': ['B00OHML39Y',
#   'B00C9J5RIU',
#   'B00ICS9TTA',
#   'B00ACVHCX0',
#   'B00IWYO5ZW',
#   'B00BSZU9AM'],
#  'B00VJKPJW4': ['B017S1KRCO', 'B00QL14R88'],
#  'B00HI3MSV6': ['B00CQUW9YC', 'B00AAS2JC4', 'B00H3ZWIYG'],
#  'B018SPCOLG': ['B00J1WU41S', 'B00YAVNORQ', 'B00S5HPW6C'],
#  'B007U7WMI4': ['B00AOS6Y26', 'B00JTCDAPC'],
#  'B00ONUYEZA': ['B00QE1J5HI',
#   'B00IWTSKBW',
#   'B00BRUQ7JK',
#   'B00NRQWATI',
#   'B00CNQ7BG0'],
#  'B00D54THLQ': ['B00GW9SOBK', 'B00GXBV0MM'],
#  'B01E1HDK0Y': ['B01BO8423M'],
#  'B00LJAZ7W6': ['B00SPA1Z5Q'],
#  'B00I15JCPK': ['B00JBSTU0I', 'B007CIMWZO', 'B00MQ999AK'],
#  'B00ICXDRCU': ['B00QI8BV9W', 'B00KDKCMKI'],
#  'B00T94ANNM': ['B00T22Y062', 'B00ZRYDR86', 'B00TEPXICO', 'B01097AOJA'],
#  'B00GPDYL74': ['B00MWZXZKS', 'B00ALTVJ8W', 'B00INL12F0', 'B00M7ILTLW'],
#  'B016TO0AOG': ['B00U4PADZI', 'B019G0SO9S'],
#  'B01F2EXCF8': ['B00P8FU8UY'],
#  'B004K6MMCY': ['B006N09CCS', 'B0067AMY2O', 'B006GZ1VU6'],
#  'B00GNA1DFC': ['B00E6X3XY2', 'B00NOAZJI6'],
#  'B00LT9SX1E': ['B005CWJJO4',
#   'B00HJCPDVI',
#   'B005CX33HM',
#   'B00AKCVNX6',
#   'B005C5YZ86',
#   'B00JTLANOO'],
#  'B00K1OAXKM': ['B018F6H3U0'],
#  'B00GZANS6M': ['B00SPGA5T2',
#   'B00BOVLVCU',
#   'B00O8CFKKG',
#   'B00IZL6KTG',
#   'B00MR282E0'],
#  'B00BOVLVCU': ['B00CE4A8UM'],
#  'B017AJ4QFI': ['B00XYR9IE0', 'B00QL65B2Y'],
#  'B00KGREQZW': ['B00GW9K8EG', 'B00KWISN5E', 'B00M4M2PIM'],
#  'B00AOT3UDG': ['B00E7IWEFU'],
#  'B009Y89HJE': ['B00MWZXZKS', 'B00M7ILTLW', 'B0091GZ1GC'],
#  'B00K40M50E': ['B0078IPNCW', 'B004V49BLU'],
#  'B00PW1FVXI': ['B00PSLJDOU', 'B012U86IBY'],
#  'B006R7FXFW': ['B00CSBQ5YO', 'B0057QO8Q4'],
#  'B0067LH1QC': ['B004XW3LLQ'],
#  'B005G7ZFXY': ['B00OE8JKNW', 'B00MO3GPFU', 'B00BV0IM9E', 'B00JX5YROI'],
#  'B00PYYA7VY': ['B00OOBJMEG', 'B00CBWM0BW'],
#  'B010EJQT6K': ['B0067AMY2O', 'B00UKKMKD0', 'B00V8CETHO'],
#  'B00NAI37LS': ['B00KVQZSF0', 'B00MWZXZKS', 'B00HY0GTYK', 'B00M7ILTLW'],
#  'B00I6KTA20': ['B00HNWEA9K', 'B00QE466KY', 'B00ETEB5QQ', 'B00K31DCD8'],
#  'B00AZKPNRA': ['B0175GJZE8',
#   'B0090W7ZB6',
#   'B00P32ZUAK',
#   'B00AJUVJN8',
#   'B007XYIGR0'],
#  'B00B7VP6EG': ['B00AA3P7M8', 'B017R65QS0', 'B00EMG3A00', 'B00GVB3NQA'],
#  'B018BYUPVA': ['B00U0F0VGI',
#   'B0145COWD4',
#   'B00ZYAZFC4',
#   'B019DFM1WM',
#   'B01757MBGG'],
#  'B00PG4T6UU': ['B00J8QG7BI'],
#  'B011J6ZTE0': ['B00KTCBXSC', 'B00M0EUU22', 'B00WT2BNJ4'],
#  'B00WZWMRC0': ['B01317ZZLC'],
#  'B009A21KSK': ['B007PW331E', 'B0073SJELI'],
#  'B01EDDUAFE': ['B01C4IAK5U'],
#  'B01B6WT11Y': ['B00L1R3OS6'],
#  'B00L2CNSL8': ['B00RBQ56KA'],
#  'B00GVQOJZ4': ['B00IOSBC3Y'],
#  'B00DPWZ2J4': ['B00CKURM1I',
#   'B00BMU2VEK',
#   'B00C5VPHTQ',
#   'B00G1O9CJ4',
#   'B00DH8T4DG'],
#  'B0160G011K': ['B00M8QQMC4', 'B00JNU6GLK', 'B00L2V73GK'],
#  'B0110Z9SSI': ['B00SPA1Z5Q', 'B00TCSWFX6'],
#  'B00BXGUOU6': ['B00Z318GNY'],
#  'B00COAKA7C': ['B00CMV4N7Q', 'B00CLYSN4I', 'B00CHVWF9O'],
#  'B00IXR3JLE': ['B00ZZNF0TS', 'B00J1MW06U'],
#  'B00LNMM6SI': ['B008YJLDY6', 'B00BR04UE4', 'B00FGJVK1I', 'B00C7Y0T8A'],
#  'B006DJSRIO': ['B00GWF5ETE', 'B007HS1C4Q'],
#  'B00MUSS2ZA': ['B0110QWBTK', 'B00PQPJMWG'],
#  'B003XVYJ2S': ['B002TG4MPM', 'B002TLTL8K', 'B002SVQD0A', 'B002D48NBO'],
#  'B00YQ3UDM2': ['B015F1XMS0', 'B014C4JDDE', 'B0139HKO3S'],
#  'B00H9QVYU8': ['B00FXBTYOO', 'B00FDX59UA'],
#  'B00RXZXOWQ': ['B0117VIQRE',
#   'B00S776ER6',
#   'B00ZTMRHQ4',
#   'B00T0WXD8K',
#   'B00U89TGNU',
#   'B00RYC3A3Q',
#   'B00VH4UFMG'],
#  'B014PN8XL0': ['B00YQD91RA'],
#  'B005JVSU2U': ['B0051EZBRM'],
#  'B00FEVBUPE': ['B00HM6Y632'],
#  'B00TC1W3D0': ['B010OTOMCS', 'B00O2BS4O2'],
#  'B00UJOUELW': ['B00VQNZ0JQ', 'B017I166EW'],
#  'B00LOTFY1Q': ['B00OGXJF7G', 'B01E6FF7AW', 'B00RC4MNWK'],
#  'B00MQ00LEM': ['B00HZ3RTM2', 'B00K2BX8WY'],
#  'B005GVY46E': ['B00N98FD3O', 'B00I513YAY', 'B00658O12E'],
#  'B00IGVA8SE': ['B00KQ4FVLS'],
#  'B00BV0IM9E': ['B00GEHN8ZW'],
#  'B01GPL2AGE': ['B01BA27G4E'],
#  'B00NRWI91U': ['B00L0LQCQ4'],
#  'B00M0DQIEC': ['B00MUW6TF6'],
#  'B00H9S73D8': ['B01F0RT26K',
#   'B017RZ41BE',
#   'B00LP3ULFU',
#   'B00FZ5H8Q4',
#   'B00O5B3M4G'],
#  'B00PD8LQ6G': ['B01DX3EA06', 'B00CYRH3H0'],
#  'B00BIVE59M': ['B01CKECZQ0', 'B00480P5TE', 'B007LS0JQE'],
#  'B005QEA87A': ['B006M6XV1Q'],
#  'B00FZ2EK54': ['B00HN9G1BS'],
#  'B018RKHYMQ': ['B01BCTMJZ6'],
#  'B00BMU2VEK': ['B00N8G9PFO', 'B00HNWEA9K', 'B00J8UD1OK', 'B00K31DCD8'],
#  'B00MBQASMQ': ['B00TQ70PMG', 'B017S1KQ0M', 'B00H8XIAZ4', 'B00MBQASGC'],
#  'B01EWEWRQ4': ['B00PW1FVXI', 'B00IKW40N8'],
#  'B0068XJXJC': ['B00CCH4WKI', 'B00BANV988', 'B00E37365C'],
#  'B006H96RO6': ['B007JP85IS', 'B00ALTVIJM'],
#  'B00LZFHF1G': ['B00K31DCD8', 'B00JTCDAPC', 'B00M3GWXHW'],
#  'B00CJNDKUS': ['B00G2CU49M'],
#  'B00CKH0X2G': ['B00BAW3ZG8', 'B00BMU2VEK'],
#  'B00MC41BHI': ['B00HBX7DD6', 'B00QSAWMKC'],
#  'B00NN92YPY': ['B00R4ZHYXK', 'B00D53OFPA', 'B00O55GSW0'],
#  'B00QNZGJVA': ['B00KVQZSF0', 'B00HY0GTYK', 'B017KUZUM0'],
#  'B00A2WZ1IC': ['B00B8ZR41E', 'B017733NZ6'],
#  'B00IJFYICO': ['B00DVWRDN6'],
#  'B00OBRHV3M': ['B00PSEO3XS', 'B00KMB9SG4', 'B0147H31BG'],
#  'B01AJ6SEOS': ['B017KRJP7Y', 'B00QZABE5O', 'B00DLATS18'],
#  'B00H6Q2D06': ['B00EXFFVHA', 'B00FZ2EK54'],
#  'B00QPDKAM4': ['B00K2BX8WY', 'B00HZ3RTM2', 'B00MQ00LEM'],
#  'B007YIZ2YA': ['B00EMG3A00', 'B00M3GWXHW'],
#  'B01D7GSS70': ['B00M27P9D2', 'B00DMR0NTQ', 'B012D9R9J0'],
#  'B00W22ITCU': ['B00F5DF9QC', 'B00DTIBSMY', 'B00B4Y2UHW', 'B00NHDEB34'],
#  'B014TINW0I': ['B012YKI6D6', 'B00BN1P6Z4'],
#  'B00T0T2JE2': ['B00LZA6C88', 'B00T85X6OU'],
#  'B00LDQXAX4': ['B00MWZXZKS', 'B00KVQZSF0', 'B00M7ILTLW'],
#  'B00FA11TTU': ['B00CKH0ZDS', 'B00P1JG7Q6', 'B00CHP64IS'],
#  'B00457VKIA': ['B00FQAQQ9I'],
#  'B00OX60XLS': ['B00KFMRU5Q', 'B00JZWDC9K'],
#  'B00BYLQUGM': ['B00FIWMEU4', 'B00H3LM7UA', 'B00EOKKVG0'],
#  'B00MJFY5HS': ['B00WF8YBRS', 'B00NK0MK8C', 'B00BL6CDCA', 'B00M3GWXHW'],
#  'B01HDLC4C0': ['B016YX01U0', 'B01CXRI0W2'],
#  'B00H91ZMGU': ['B00KKTTQZQ', 'B00PCMBFGY'],
#  'B019AJC8DS': ['B00GU460T0', 'B00PQV6H78', 'B01H5MF0JG'],
#  'B0157GPPEM': ['B00U9U223Y'],
#  'B00O3V6PWY': ['B00HLPNH84'],
#  'B01F5KX678': ['B00BLMHY8M', 'B00E51MK76', 'B00G8UKDQ2'],
#  'B00HBF56E2': ['B00YJCJGEG', 'B00C2L7N4G', 'B00EFWU91E', 'B00P32ZUAK'],
#  'B007HS1C4Q': ['B006DJSRIO', 'B00GWF5ETE', 'B0092K075C'],
#  'B01H5MF0JG': ['B00KRRWLCQ', 'B00MZAS07S'],
#  'B00OCSZSQM': ['B00GOGXV5A', 'B00JRBN26M'],
#  'B009IAMZGU': ['B00ZZNF0TS', 'B01GP9AIAQ'],
#  'B00NMVS01K': ['B00ICC4CH0', 'B010W9HEUW'],
#  'B0122DECEW': ['B00U9U223Y', 'B01BS8D2M0'],
#  'B00F70LNO0': ['B00E9LXPIU', 'B00MT0UR3Y'],
#  'B00HFKOM0W': ['B00GOGXV5A', 'B00JRBN26M'],
#  'B00FP8QLTG': ['B01H3Z1YTU', 'B00PR355UA'],
#  'B00BSB5B2M': ['B00L8CO9LK', 'B00IMP3N86'],
#  'B014X8T898': ['B00PBUEQJK'],
#  'B00NH2QTC6': ['B00I52PPT6', 'B00MY6POOK'],
#  'B00AOS6Y26': ['B007U7WMI4', 'B00JTCDAPC'],
#  'B00L7UT8GE': ['B00LP3ULFU', 'B00KI4KIC8', 'B00O5B3M4G'],
#  'B00M3GWXHW': ['B00NK0MK8C', 'B00EMG3A00'],
#  'B00AB1ZGX4': ['B00DU2IYVM',
#   'B00CKZQFSY',
#   'B006Q1V2XQ',
#   'B00QNYKI7C',
#   'B01AAXMLVW'],
#  'B00NJ0F5Y4': ['B00NJ0Q0SY'],
#  'B00UGEZ5EQ': ['B01GW1BZBI'],
#  'B00IPIMWUK': ['B00R6K0JM6', 'B00I0ZF9VM', 'B00JH7933W'],
#  'B00N6V3QMY': ['B00DRF2602', 'B017J0798O'],
#  'B00NTN7M4C': ['B00QI8BV9W', 'B00LNMM6SI', 'B00GVB3NQA'],
#  'B005NTW8SU': ['B00LS61SL0'],
#  'B00FHKS1KO': ['B00ECBI0PK', 'B00MXS70SW', 'B00ECC6132', 'B00GMWKE2Y'],
#  'B00R40ON3Y': ['B008QPB2TY', 'B00QSAWMKC'],
#  'B00C52CBDK': ['B005JT5DP4'],
#  'B00GRAZD3G': ['B00ET55NGS'],
#  'B00C126RFM': ['B014RVEJ4U', 'B00KUJCVLC'],
#  'B00JTIOYOM': ['B00PR355UA', 'B00JTDZ1YE', 'B006S3FAR6'],
#  'B006H6AOK2': ['B00G15AKGC', 'B003L78146'],
#  'B00GAPQ4FO': ['B00EH2N8RO'],
#  'B007LQJNM2': ['B00TYYW7M2', 'B0070DZI70'],
#  'B00T0WXD8K': ['B0117VIQRE',
#   'B00S776ER6',
#   'B00RXZXOWQ',
#   'B00ZTMRHQ4',
#   'B00U89TGNU',
#   'B00RYC3A3Q',
#   'B00VH4UFMG'],
#  'B00LI485VI': ['B00N05R39I', 'B00LZXYZK2'],
#  'B00FDX59UA': ['B00FXBTYOO'],
#  'B00XM7VJMG': ['B00R4Y1MMK', 'B00KFZCAAI', 'B00KFXAPNE', 'B00SJ7LQ9K'],
#  'B014T6L87E': ['B00T7XXV3Y',
#   'B00U48LDN6',
#   'B014GCDQ62',
#   'B00TU7C7K0',
#   'B01297KYDO'],
#  'B00TQ8W4KG': ['B00BD63EIK', 'B00DHVERWQ'],
#  'B00NO7EREQ': ['B00HYD1F2S', 'B00SW8HQSQ'],
#  'B01FKDKB96': ['B01G3UFLMM', 'B01BQ00CAA'],
#  'B00NDEO7T0': ['B00HBWQCAC'],
#  'B00P1XE0QG': ['B00HZZNBZ4', 'B00U48LMGO', 'B00CRHLJQI', 'B00L3LR7VU'],
#  'B00QPJNNIQ': ['B00O4GUH1S'],
#  'B00XSYKTKQ': ['B0085WDNMW', 'B00772HW1O'],
#  'B00SSS98IQ': ['B00L2K4D0U', 'B00WDD5IKO'],
#  'B00URIUBJU': ['B00BQYNNE4', 'B00VRQNK58', 'B00UY3LLY2', 'B011HC6Y1I'],
#  'B01EH5IRI0': ['B00HFYQ346', 'B00FE3R0GU'],
#  'B00B3YJK4E': ['B00CX9K2FE', 'B00F7CJKAC'],
#  'B007JCSNDI': ['B00957XZFG', 'B00E9F6X5S'],
#  'B00FHIZMP8': ['B00HDDLONY', 'B00I28TY2C'],
#  'B01F454WU4': ['B01GRAJS8Q', 'B01AB1EQL6', 'B00HMXLW9Q'],
#  'B00FA2B9S0': ['B00AQU7FTS',
#   'B00D64UYTE',
#   'B00TXZYQWG',
#   'B00BEQP450',
#   'B00GBFJ1IA'],
#  'B00E5JAIP4': ['B00DOJ93PC', 'B00GY34GUM', 'B00HHGRE22'],
#  'B0196OKEEC': ['B01DH6EQ9O',
#   'B005DPIINI',
#   'B00P32ZUAK',
#   'B00AJUVJN8',
#   'B005LVV6DI',
#   'B01FSDI7H6'],
#  'B00GOZ7X8M': ['B00ESJ3S94'],
#  'B00EAEFYU8': ['B009H8LB0E',
#   'B00M122F7Q',
#   'B00EZE88SS',
#   'B00MQ2NCY6',
#   'B00C112NVK',
#   'B00AB1NJV0'],
#  'B015DD47B6': ['B015UO8NQ8', 'B010W9HEUW'],
#  'B00X7R3DFM': ['B014LQ18CW', 'B00HVFAY1M'],
#  'B00D3R66N2': ['B00CD7QO5S'],
#  'B00F9Z458E': ['B00ESJ3S94'],
#  'B00N20V1BC': ['B00YO2UO9M', 'B00MO3GPFU', 'B00UY3LLY2'],
#  'B00W4LYJ6Y': ['B00XPKE8GY', 'B00DZSOC62'],
#  'B00JBIDUYA': ['B01DS8E83A', 'B00QVNQYIM', 'B018QZB1IA'],
#  'B0092ML9AC': ['B00CC68FLG', 'B008VKXOIQ', 'B00AND5YIM', 'B00CV30X8I'],
#  'B0091I2S3Y': ['B00DH8T4DG', 'B00BD63EIK'],
#  'B00AR5H52E': ['B00A9I4UWC', 'B00HBXVCEM'],
#  'B00SHV3CNG': ['B00Y9H7M0G',
#   'B00I1U1FP0',
#   'B010MPIN1K',
#   'B00YLPMA8K',
#   'B01CUOPVZW',
#   'B00PSPFPSO'],
#  'B00PG3NQBQ': ['B00INIXG66', 'B00769KFS0', 'B00AEDDSN4'],
#  'B00E7IWEFU': ['B00AOT3UDG'],
#  'B00SPGA5T2': ['B00BOVLVCU',
#   'B00GZANS6M',
#   'B00O8CFKKG',
#   'B00IZL6KTG',
#   'B00MR282E0'],
#  'B00EMLEY5U': ['B00C0ZU6AM'],
#  'B00NLZ02Z4': ['B00DP8R3P4', 'B00GW60KC4', 'B00L0OKIT8'],
#  'B00HUXNM6O': ['B00HJCPDVI', 'B005CX33HM', 'B00AKCVNX6', 'B005CWJJO4'],
#  'B016FYUGN0': ['B00U9U223Y'],
#  'B00ET57O8I': ['B00ECBS5OQ', 'B00A8PYYOA', 'B00GBIYX8A'],
#  'B01BU7PHA4': ['B00H9KEAKA'],
#  'B01BYQ6XKO': ['B006ZAGYEK', 'B004YKUNYA', 'B00EBRU0NK', 'B006ZO9U88'],
#  'B00HTJJST4': ['B00K9O53UO'],
#  'B005SVVFL4': ['B00WRNKOOU'],
#  'B005ISCTW6': ['B00SJ7LQ9K', 'B0064BYJN8'],
#  'B00N58K6QW': ['B01BN5LB7Q', 'B00PISYDD4'],
#  'B013AOYW4C': ['B01FIS2F42'],
#  'B005DEWINK': ['B005IAQ7YU', 'B004SI455Q', 'B006LR8UQW'],
#  'B00K6S71RG': ['B00L8A3BMK'],
#  'B00EZ5N6Z2': ['B00L48ZXN6', 'B00L8H2AJI'],
#  'B00NUUO3P0': ['B00J0CAR16'],
#  'B00VH4UFMG': ['B0117VIQRE',
#   'B00S776ER6',
#   'B00RXZXOWQ',
#   'B00ZTMRHQ4',
#   'B00T0WXD8K',
#   'B00U89TGNU',
#   'B00RYC3A3Q'],
#  'B00BMU99HM': ['B00OO4LIS6', 'B0058EU1Z2'],
#  'B00IDAYY10': ['B00K31DCD8', 'B00HNWEA9K', 'B00JTCDAPC', 'B00M3GWXHW'],
#  'B00EFWU91E': ['B00HBF56E2', 'B00YJCJGEG', 'B00P32ZUAK'],
#  'B00OGM2722': ['B00KHHOUKW', 'B00MUXSBBA', 'B00JIWJ78C', 'B00LMTLV24'],
#  'B005L5UOV4': ['B00BEOZCJU', 'B00QMEK3GE', 'B00JX7UVFU', 'B005MUEXWE'],
#  'B01ELOX52U': ['B01H304OAQ',
#   'B01D2CC1EU',
#   'B01CDYARAS',
#   'B01GSL9C3A',
#   'B01AIZ7ZOK',
#   'B01B5FBWR8',
#   'B01BEGXPYG',
#   'B01EVWJR1U'],
#  'B0093TFV08': ['B0098796PQ', 'B00AV4X9TO', 'B009B11BKW', 'B00R8EKHVS'],
#  'B00T3E76II': ['B00E40F64M'],
#  'B00H6S6W9W': ['B00NK0MK8C'],
#  'B00HP90OBE': ['B00RAVZRVE', 'B00MIA63WE'],
#  'B00KOYAUAM': ['B00IWTSKBW', 'B00JQUC9OA', 'B00O24Y1V4', 'B00PSPFPSO'],
#  'B00K5YPHDQ': ['B00INIXG66', 'B00769KFS0', 'B00AEDDSN4', 'B00BYLQUGM'],
#  'B00QZCYET0': ['B00K31DCD8', 'B00HNWEA9K', 'B00JTCDAPC', 'B00M3GWXHW'],
#  'B0081H2KH0': ['B00BJCBPIO'],
#  'B00FL3VPD2': ['B00DE3MJ8G'],
#  'B00B0J815Q': ['B00BMU2VEK'],
#  'B01H4NVSOC': ['B005GVY46E', 'B00ASFU5NO', 'B00EAOUCQ4'],
#  'B00FD7Z51O': ['B010F3PVVY'],
#  'B016XEZDB2': ['B013KWCLA6'],
#  'B00FE1MVS4': ['B00FKBSDMQ'],
#  'B004AYCTLA': ['B00UY3LLY2',
#   'B00C8VW0JS',
#   'B00F4BWD46',
#   'B00B3NX16I',
#   'B004HO5ZY6',
#   'B004E9U9AY'],
#  'B00HQSEA96': ['B00EI5XX7U', 'B00QI8BV9W', 'B008V1UB86', 'B01FVHS6OI'],
#  'B00NWVA036': ['B00CGFJ1BQ'],
#  'B00I48KN16': ['B00P46P3XY', 'B00HH1JVCI', 'B00LXNM46G'],
#  'B017XVQCZU': ['B0130LQWBG', 'B00W0EETII', 'B015424GP8'],
#  'B0110QWBTK': ['B00XCLU7Z2', 'B00MUSS2ZA', 'B00XFAAGPG'],
#  'B017GQDZWU': ['B00SJE6XNC'],
#  'B00LUC227G': ['B00MD4TX68', 'B00JJY2XX0', 'B00N00N4UK', 'B00O27QJIE'],
#  'B00VPL5I1Y': ['B00TUMS0CO', 'B00U9U223Y'],
#  'B01CDF5PWW': ['B00YQD91RA', 'B00FHFODOM'],
#  'B00HWI04XQ': ['B00PBUEQJK'],
#  'B01GPEDC3G': ['B01BTHWXF2', 'B01E4AF6VO'],
#  'B00CJEUVGS': ['B00SJ7LQ9K', 'B00GYLAZJU'],
#  'B00G8IJ75W': ['B00HGI16I4', 'B00ZJ5YDW2', 'B00UMODJ4I'],
#  'B006DTZ0KC': ['B00NK0MK8C'],
#  'B00XCLU7Z2': ['B00MK395JM', 'B0110QWBTK', 'B00XFAAGPG'],
#  'B00D0S8PZQ': ['B00DH8T4DG', 'B00BD63EIK', 'B00BMU2VEK'],
#  'B00BNRJAW8': ['B00KK9I08A', 'B00K1HQWBS'],
#  'B008XDGQ2W': ['B00C52CBDK', 'B00OQY2X06'],
#  'B017JA1SFO': ['B01FCRUS84'],
#  'B00EDYR1TM': ['B00OCZDME0', 'B00K0N2SRA', 'B00GB36DDI', 'B00GNRGP2G'],
#  'B00SAQZ6H8': ['B00ID2A1PQ',
#   'B00JE1ZMSG',
#   'B00M4P6J40',
#   'B00WDS8CYI',
#   'B00SAXPU3G'],
#  'B00XNLIPOG': ['B018WYKTR4'],
#  'B00XTAEA90': ['B017I166EW',
#   'B00VQNZ0JQ',
#   'B00S7KU0I2',
#   'B00NMOMJA0',
#   'B00UJOUELW'],
#  'B00JCG6T94': ['B00I1SQBUQ', 'B00LDUVA4G', 'B00B3F04U2'],
#  'B003AKY45Y': ['B00IHN8U0Y', 'B00JD28AJ4'],
#  'B0156VKOBW': ['B00CQB2IPG', 'B00NE0CCD6'],
#  'B00K3698M2': ['B00I4KRGPA'],
#  'B01867IG7W': ['B00YO2UO9M', 'B00U4CW5W0', 'B00UY3LLY2', 'B00DE50LTS'],
#  'B00N7LVV0M': ['B00DX5DHQS',
#   'B00903I7U8',
#   'B0121F21ZS',
#   'B00IWUKUVE',
#   'B00MU30LA4'],
#  'B00JWTGGVC': ['B00PNU8Z86', 'B00HG5JL34'],
#  'B006U1N37U': ['B00PBUEQJK'],
#  'B0094HZVWC': ['B00ENQEM9M', 'B00BP5DNTE', 'B00BJCBPIO', 'B00GZR2NZC'],
#  'B0153JH4TC': ['B0110QWBTK'],
#  'B017HQ56CQ': ['B00V3N8MF8', 'B00P6P9HHQ', 'B00JNRLOEW', 'B00IMNWM3K'],
#  'B00FE3R0GU': ['B00HFYQ346'],
#  'B00LD1M7I8': ['B00L01GJAS', 'B011GDT154', 'B00LD1OI5I'],
#  'B00TYYW7M2': ['B00Y9H7M0G', 'B0070DZI70', 'B007LQJNM2'],
#  'B018DFEOFA': ['B00Y5VOAOW', 'B00L0Y84QC'],
#  'B00UJEGURO': ['B00H9KEAKA'],
#  'B00F77FFMO': ['B00LXQIL06', 'B00OOAXT28', 'B0110QWBTK'],
#  'B00D2KTTHK': ['B00A9FYVXS', 'B00DMLQH8I'],
#  'B00EAZA9AC': ['B00FH4FKZE'],
#  'B00FKERXXS': ['B00YOAZYYY', 'B00C5R83E6', 'B00Q5DLY42', 'B00TJ3G4U4'],
#  'B01HC1252A': ['B0091T62FS', 'B01GF9OSI4', 'B01GYPQQRU'],
#  'B00ILWP2NO': ['B00PEXI4BU'],
#  'B00S7766OW': ['B00MXFOMD6',
#   'B00U0F0VGI',
#   'B00ZYAZFC4',
#   'B019DFM1WM',
#   'B01757MBGG'],
#  'B00TWUUBUI': ['B00RZT2U5W'],
#  'B00QPD85SK': ['B00NRCDS66',
#   'B00M7ILTLW',
#   'B013KWCNL8',
#   'B00TI0T5IQ',
#   'B00HY0GTYK'],
#  'B00OEOF882': ['B00MQCND7W', 'B01BHE3H1G'],
#  'B0145COWD4': ['B00LD6IYUS'],
#  'B00EXV57LO': ['B00IA4UVPC', 'B006RZNR3Y', 'B00LJAZ7W6', 'B00UY3LLY2'],
#  'B00CX9K2FE': ['B00B3YJK4E', 'B00F7CJKAC'],
#  'B00K7UH84O': ['B00JM2HG18',
#   'B00OJG202W',
#   'B00L2FG1Y6',
#   'B00N27UEPE',
#   'B00KZ6LWWO',
#   'B00MJPJ56O',
#   'B00O5OLJ0C'],
#  'B00SXNYCU0': ['B00SWAXORQ'],
#  'B00C112NVK': ['B009H8LB0E',
#   'B00EAEFYU8',
#   'B00M122F7Q',
#   'B00EZE88SS',
#   'B00MQ2NCY6',
#   'B00AB1NJV0'],
#  'B00O2BS4O2': ['B00YN6XHMU'],
#  'B0057QO8Q4': ['B00BV0A5SK', 'B00GVMSFQM', 'B00E7KTERY', 'B006CC6ZTU'],
#  'B00TLFMPX0': ['B015YDZ4XA', 'B005KV1EHW', 'B00WQLAI7Q'],
#  'B010K7B5E2': ['B00CJ3UPTW'],
#  'B01B3G5X8I': ['B01BFYBH24'],
#  'B00FXC3FQ6': ['B00FXAG6MS'],
#  'B00N98FD3O': ['B00I513YAY', 'B00Q5IJ55C'],
#  'B00GZR2NZC': ['B00ENQEM9M', 'B0094HZVWC', 'B00BJCBPIO', 'B00BP5DNTE'],
#  'B00C0D2MAQ': ['B00CBWM0BW'],
#  'B00TEPG4HK': ['B01HCB4LAO', 'B00ESV9MFG', 'B01B43XFKI'],
#  'B00PM3YS8U': ['B00CQAPXOU', 'B00LT9SX1E', 'B00G05X52E'],
#  'B01DS8E83A': ['B00JBIDUYA', 'B00F3G29QY', 'B018QZB1IA'],
#  'B00HE4Z51Y': ['B0090W7ZB6',
#   'B00P32ZUAK',
#   'B00C2L7N4G',
#   'B005LVV6DI',
#   'B009BZFQ4U',
#   'B00N5JBZ5C',
#   'B007XYIGR0'],
#  'B00N43YDOY': ['B00JTCDAPC', 'B00JZ6W9WC', 'B00HLIYVPE'],
#  'B00A8PP8IQ': ['B00KKTTQZQ', 'B00BZF0H6G'],
#  'B00KBHHAYG': ['B017ATNDY8', 'B00KBH7JDI'],
#  'B015VKB8KY': ['B00DLSTT9Q',
#   'B00W3QA7VG',
#   'B014Z40CGI',
#   'B00EH2E5IK',
#   'B00CS98VC0'],
#  'B01FTEBE74': ['B016YIRT9Q'],
#  'B00C5R83E6': ['B00FKERXXS', 'B00YOAZYYY', 'B00Q5DLY42', 'B00TJ3G4U4'],
#  'B006CT0J0E': ['B006PVGZ0W', 'B00QVNQYIM', 'B007YUYWPS'],
#  'B00AK2UISW': ['B00YAKL5A0', 'B00ADVB4YC', 'B00A6EIA20'],
#  'B0058OJ8AG': ['B00I7BC9A8', 'B00QU63A9Q', 'B00BLOI13C'],
#  'B00DPAFPQG': ['B00G2CU49M', 'B00CJNDKUS'],
#  'B00BG9Q0BW': ['B00JCELEZ0', 'B00UE3T6AI'],
#  'B005D4Y5LS': ['B006N09CCS', 'B006GZ1VU6'],
#  'B00BRUQ7JK': ['B00CNQ7BG0', 'B00QE1J5HI', 'B00DFIE9NI', 'B00IWTSKBW'],
#  'B01E6DT75U': ['B00YV666B6', 'B00A9HW1CY'],
#  'B00HHGRE22': ['B00E5JAIP4', 'B00GY34GUM', 'B00DOJ93PC'],
#  'B00CIHLV6K': ['B00FRXNHVY',
#   'B00BEOYH0U',
#   'B00DVYIQDA',
#   'B00BW73VVU',
#   'B00ESPZ2C4'],
#  'B00EY2UDR0': ['B00D2Y3BFC'],
#  'B00N2AHDHI': ['B00JAQX4HQ', 'B00NKQP7VS', 'B00QXWYEYW'],
#  'B00C6NBTPE': ['B00D6XE2GQ', 'B00BC6SSKU'],
#  'B00D3OASKM': ['B00FIWMPJO'],
#  'B018SPRUME': ['B00KKXTC2Y', 'B00SK8S8KS'],
#  'B005JT5DP4': ['B00C52CBDK'],
#  'B01BW83B72': ['B01B9XNJP4', 'B00S6ROWI0'],
#  'B00CJ1ICH6': ['B00DH8T4DG', 'B00BD63EIK'],
#  'B00HLPNH84': ['B00O3V6PWY'],
#  'B00D53OFPA': ['B00NN92YPY'],
#  'B00SIMWOY2': ['B00EC197UC', 'B014GMDJA0'],
#  'B00L1R3OS6': ['B00GSF4Z20'],
#  'B00PPDJ7OW': ['B00IJYII4E', 'B00AK4SWUQ'],
#  'B00CFAGTV2': ['B00EHSUFD8', 'B006ITXEVO', 'B00GI9969I'],
#  'B00DU2IYVM': ['B00CKZQFSY',
#   'B006Q1V2XQ',
#   'B00QNYKI7C',
#   'B00AB1ZGX4',
#   'B01AAXMLVW'],
#  'B00GBIYX8A': ['B00H0GED9Q', 'B00ECBS5OQ'],
#  'B00QHBKNB2': ['B00S5Q1W2G', 'B00QZHHE7E', 'B00NUDPR66', 'B01EMF4FXG'],
#  'B00ICTKZOM': ['B00EWVIA64'],
#  'B00BRKQY8Y': ['B00HE4Z51Y',
#   'B0090W7ZB6',
#   'B00C2L7N4G',
#   'B00P32ZUAK',
#   'B0069FJE4S',
#   'B005LVV6DI'],
#  'B016ZG19KM': ['B00GVZZQ2A', 'B00JWVVXEU', 'B00KSNA2R0'],
#  'B00HFXK4W4': ['B00FBK17PQ', 'B00IRNT56M', 'B00PPWM0SS'],
#  'B00SK8S8KS': ['B018SPRUME', 'B00KKXTC2Y'],
#  'B00MRFP7E0': ['B00MD4TX68',
#   'B00LUC227G',
#   'B00JJY2XX0',
#   'B00Q3DXVSG',
#   'B00HNZP85M',
#   'B00ICVCL1A'],
#  'B012LI0F9E': ['B00CBWM0BW', 'B00VN6WJFO', 'B00B4DKWUU', 'B0100V6A6G'],
#  'B00DDU756Q': ['B00QI8BV9W', 'B00KQ2DC1Q', 'B00LNMM6SI'],
#  'B00DXIFORA': ['B00A8PYYOA', 'B01GM4MH6C'],
#  'B00CMXCWW2': ['B00J4YNHU8', 'B00LP3ULFU', 'B00KI4KIC8', 'B00L7UT8GE'],
#  'B00KKFTAU6': ['B00OME9OQQ', 'B00K7Q8I1A'],
#  'B007Z4WTBW': ['B00MCT40XU', 'B00FTP60FU'],
#  'B00DVWRDN6': ['B00IJFYICO'],
#  'B008XP6652': ['B016TO0AOG', 'B00U4PADZI', 'B019G0SO9S'],
#  'B00769KFS0': ['B00AA0VB8U', 'B00A9HW1CY'],
#  'B00DG261NY': ['B005DPIINI',
#   'B00DG261UW',
#   'B00P32ZUAK',
#   'B00DG26170',
#   'B00E3C2O7S'],
#  'B00IX3QJO2': ['B009H8LB0E',
#   'B00EAEFYU8',
#   'B00M122F7Q',
#   'B00MQ2NCY6',
#   'B00JMRE4L8',
#   'B00KCX47VI',
#   'B00GWPCIL6'],
#  'B01A1E8WO0': ['B01CV6HR2E'],
#  'B00JXW6GFE': ['B00E40F64M', 'B008DDW4OQ'],
#  'B019VJ697I': ['B015BH04E8', 'B00RY2IAMM'],
#  'B00DG261UW': ['B005DPIINI',
#   'B00P32ZUAK',
#   'B00DG26170',
#   'B00E3C2O7S',
#   'B00DG261NY'],
#  'B01C8CLGR8': ['B005O54AOI', 'B00GVZZQ2A', 'B00SWF7O7M', 'B00I9J9XAM'],
#  'B010C0Y77O': ['B00V5850OW'],
#  'B007GSO4XS': ['B00BW73VVU', 'B00ESPZ2C4', 'B00BEOYH0U', 'B00DVYIQDA'],
#  'B00HMUUFJC': ['B00FPCJSYC', 'B00CMU1IN4'],
#  'B00MIH3P0U': ['B00K6GZJ68', 'B00OME9OQQ'],
#  'B00IHN8U0Y': ['B00JT2PXB6', 'B00JD28AJ4'],
#  'B00AQIGNPC': ['B007YIZ2YA', 'B009XFD76M'],
#  'B011TI8CTW': ['B015ECXJOM', 'B00ZAJTPB6'],
#  'B00FJFV6AY': ['B00D7WKQRA'],
#  'B00KBH7JDI': ['B017ATNDY8', 'B00KBHHAYG'],
#  'B00CMXSLQS': ['B00H3I2172', 'B00MOXRBWQ', 'B00IJNDYV2'],
#  'B00EWRZG5Q': ['B00RC4MNWK', 'B00ESJ3S94'],
#  'B00D6GDY1W': ['B00P38D704', 'B016WM67OC', 'B00QSE28XO', 'B00KB4GHWA'],
#  'B00CHP64IS': ['B00CKH0ZDS'],
#  'B00PMDOW54': ['B00P86K1J6', 'B00OM12RWM', 'B00UY3LLY2', 'B00QESA0OI'],
#  'B00V5855UG': ['B00ZYAZFC4', 'B00U0F0VGI', 'B019DFM1WM', 'B01757MBGG'],
#  'B00NUDPR66': ['B01EMF4FXG', 'B00S5Q1W2G', 'B00QZHHE7E', 'B00QHBKNB2'],
#  'B00DK8AQ94': ['B017ATNDY8', 'B01CJ37JJ0', 'B00HM6Y632'],
#  'B00PYD4F3Q': ['B00C44H0OE', 'B00JYFN3GA', 'B00P6Q9A04'],
#  'B00CVCGYJQ': ['B00X8SCJCS'],
#  'B00CLYSN4I': ['B00CMV4N7Q', 'B00CHVWF9O', 'B00COAKA7C'],
#  'B0085WDNMW': ['B00772HW1O'],
#  'B00KVQZSF0': ['B00MWZXZKS', 'B00M7ILTLW'],
#  'B00C11XQLG': ['B010JA571W', 'B00LD69NIA'],
#  'B00AMIH8Y6': ['B00GNTLLFK', 'B00DOOXQSM', 'B00BRW1A04'],
#  'B0197OZW7A': ['B0182BBNFO',
#   'B01C7NYWBK',
#   'B00I249HGY',
#   'B01CF7VTQE',
#   'B00APKK5J6'],
#  'B01AX5Y0NY': ['B00LNJ4ABC', 'B00M7E63YO'],
#  'B00ARON0OW': ['B00GPP30O2', 'B01FSDI7H6', 'B00SW7PCQK', 'B00C5R83E6'],
#  'B008HUP9NI': ['B009G9LJKG', 'B0092WQ7BS'],
#  'B00VPMQTKW': ['B018F3C1KU', 'B00Q6Q5ZP2'],
#  'B00UZM2O52': ['B00INIXG66', 'B01BO8423M', 'B00BK50QYY', 'B00AEDDSN4'],
#  'B00LZA6C88': ['B00IFEMVHI'],
#  'B00QLA3DKC': ['B00JRJXGWO', 'B00PISYDD4', 'B00MJ2232K'],
#  'B00TEB4HAU': ['B015L2UR1S'],
#  'B00CCVVKMW': ['B00F2TFH5W', 'B00OYWP438', 'B00YN6XHMU'],
#  'B00U9I7K6U': ['B00JV0YWC2'],
#  'B00DN6QQ3S': ['B00TFKJ4NK', 'B00E6QFG80'],
#  'B0134EZGY8': ['B00OO65H90'],
#  'B00AABHU70': ['B00ZO50HZO', 'B00A946MNQ', 'B00L2X37QS', 'B00L0LQCQ4'],
#  'B014C4JDDE': ['B015F1XMS0', 'B0139HKO3S', 'B00YQ3UDM2'],
#  'B016QIBZC6': ['B00I52PPT6', 'B00MY6POOK'],
#  'B00XFAAGPG': ['B00MK395JM', 'B00XCLU7Z2', 'B0110QWBTK'],
#  'B00GBLR4K6': ['B00C2TCQUE', 'B00EMG3A00', 'B00GVB3NQA', 'B00AA3P7M8'],
#  'B01E6BA364': ['B00FFS338I', 'B017S1KQ0M', 'B005FIRJTC'],
#  'B00BAW3ZG8': ['B00CKH0X2G', 'B00HBWQCAC'],
#  'B00CK98XXK': ['B006FKBCOM', 'B00BB1BFCE'],
#  'B01DWW6H6I': ['B01FRK7VO0', 'B01BB6RGXA', 'B01A5OVNQA'],
#  'B00OQI625O': ['B00CWFAQJQ', 'B00JTCDAPC', 'B00RH751YY', 'B00M3GWXHW'],
#  'B00VS2DSR6': ['B00T4ZG74K', 'B00NOAZJI6'],
#  'B00GEHN4I8': ['B00NWR78L2'],
#  'B0165WFX2Q': ['B0091USXFO', 'B00JCYNMUU'],
#  'B017RBEKKU': ['B00P85PU8E',
#   'B01AB1EQL6',
#   'B00HMXLW9Q',
#   'B00UVMXUUE',
#   'B00Y3771OO'],
#  'B014JSBJJ4': ['B017DGXD0M', 'B01AWPTL0W', 'B00OQY2X06'],
#  'B00IQOFSDG': ['B00K9NWRHW', 'B00QQT7822'],
#  'B017EGZHFA': ['B007YIZ2YA', 'B00EMG3A00', 'B00M3GWXHW'],
#  'B00ABLJ5X6': ['B00D0AMWI0', 'B00BJCBPIO', 'B00CK8CL0W'],
#  'B007D788ZW': ['B00KSO4TKU'],
#  'B00PFFUAWS': ['B00JIIUNUC'],
#  'B00HN9G1BS': ['B00J1V124M'],
#  'B004BA52QW': ['B004D9FGD0', 'B004FEF9XK'],
#  'B00TIQ3WHA': ['B00ING5PN0'],
#  'B00NAI85T2': ['B013FRIR0O', 'B01B3LJZAA', 'B01CXRI0W2'],
#  'B00AXOSSV6': ['B00AB3KWEU'],
#  'B0100NP05Q': ['B00GH43E1A'],
#  'B00C8EUHQS': ['B00EYOTJPK', 'B00II3YH8W'],
#  'B007EFH1OM': ['B00R7573Y2', 'B00KGKCIQI', 'B00MXL10A8'],
#  'B00UXNLT1I': ['B00T6HTTZK',
#   'B00U2XYN7Q',
#   'B00RY0LMII',
#   'B016NGFTBY',
#   'B00W6MDJ1M'],
#  'B00O5OLJ0C': ['B00JM2HG18',
#   'B00OJG202W',
#   'B00L2FG1Y6',
#   'B00KZ6LWWO',
#   'B00MJPJ56O',
#   'B00K7UH84O',
#   'B00N27UEPE'],
#  'B00L83QEHG': ['B00JUV8JPS', 'B00J5327X6', 'B00INYO7MC'],
#  'B00K92ZHJS': ['B00Z4EAA5W', 'B00MZAS07S', 'B00P1NBLPO'],
#  'B01CXL5YV8': ['B00S4D0PDW', 'B00BTRSOJ2', 'B01EM3SW2S'],
#  'B00XFD9UQO': ['B00N2YX7H4', 'B016GJWEUM'],
#  'B00HMRESYI': ['B0080T6VWO', 'B0069FJE4S', 'B00HI56L8U', 'B00BNZDOFE'],
#  'B00CD7QO5S': ['B00D3R66N2'],
#  'B005Y2MYNK': ['B00C11XQLG', 'B010JA571W', 'B00LD69NIA'],
#  'B00KLSMCPW': ['B00Z1UVSK0', 'B00I8X696K'],
#  'B00IBF3PJ4': ['B00JTCDAPC', 'B00M3GWXHW'],
#  'B016X07L2U': ['B01BA8ZTBA'],
#  'B00JIIUNUC': ['B00PFFUAWS'],
#  'B00TU7C7K0': ['B00T7XXV3Y',
#   'B014T6L87E',
#   'B00U48LDN6',
#   'B014GCDQ62',
#   'B01297KYDO'],
#  'B00Q8QD76Y': ['B00J9YWGTQ', 'B00K7ND3PY', 'B00R1O4KWW'],
#  'B00ZEHLHM4': ['B00LVI1E0K'],
#  'B00W9YDVPG': ['B00PRA4CUM'],
#  'B00LVI1E0K': ['B00ZEHLHM4'],
#  'B00T71ALZM': ['B00VX75TKU', 'B00E9GQQ9K', 'B00K0YPPME'],
#  'B00IRNT56M': ['B00FBK17PQ', 'B01AIS80FK', 'B00PPWM0SS'],
#  'B00BAT1SB0': ['B01HEBU99E',
#   'B00FRXNHVY',
#   'B00BEOYH0U',
#   'B00BW73VVU',
#   'B00ESPZ2C4'],
#  'B007JP85IS': ['B00U2YDT5W', 'B00ALTVIJM'],
#  'B00KSO4TKU': ['B007D788ZW'],
#  'B00KCX47VI': ['B00IX3QJO2',
#   'B009H8LB0E',
#   'B00EAEFYU8',
#   'B00M122F7Q',
#   'B00MQ2NCY6',
#   'B00JMRE4L8',
#   'B00GWPCIL6'],
#  'B00IJCB3M0': ['B00JFGHXPU', 'B00KPF2M6U'],
#  'B00AFYBXEI': ['B017O4W3V8', 'B0064CLU0C', 'B0070JOQHM'],
#  'B00UXX3RHC': ['B00QXUN5Y4', 'B00H7IM66Y', 'B0054QCKDA'],
#  'B00LKRNBWQ': ['B008YJLDY6', 'B00QI8BV9W', 'B00Y9H7M0G', 'B00MU30LA4'],
#  'B00MZC64MY': ['B00I1VXA3O', 'B00HFU5S46', 'B00DRFQRIO'],
#  'B00JT2PXB6': ['B00IHN8U0Y', 'B00JD28AJ4'],
#  'B01H173WKO': ['B00MRM8394', 'B00B0645XG', 'B0080SA5S6', 'B00DNCONGE'],
#  'B00GQOG166': ['B00BMU2VEK',
#   'B00ANPOFBC',
#   'B00JS732BK',
#   'B00DH8T4DG',
#   'B00EI3E0T2',
#   'B00BD63EIK'],
#  'B00DPMATHY': ['B00BW73VVU', 'B00DVYIQDA'],
#  'B00OECC9VS': ['B00L2X37QS', 'B00A946MNQ'],
#  'B00JXLLAGA': ['B00JM2HG18',
#   'B00OJG202W',
#   'B00L2FG1Y6',
#   'B00N27UEPE',
#   'B00KZ6LWWO',
#   'B00MJPJ56O',
#   'B00K7UH84O',
#   'B00O5OLJ0C'],
#  'B00K3WXIFE': ['B00NHY8K3U', 'B00MS9DVPM', 'B00KTE0JJY'],
#  'B00CC68FF2': ['B00NAI37LS', 'B00TGC71K0'],
#  'B009XFD76M': ['B00O82EPO8', 'B00P81Y7X2', 'B00Q94QAAU', 'B00OM8OBJW'],
#  'B00V50VSUU': ['B00JK1ZABE', 'B013KWCLA6', 'B00OO7Y1EG'],
#  'B00KAM07RY': ['B00JFLUJ3S', 'B011Q26IJC', 'B00UY3LLY2'],
#  'B00PEXI4BU': ['B00JG6RZCU'],
#  'B00CHVWF9O': ['B00CMV4N7Q', 'B00CLYSN4I', 'B00COAKA7C'],
#  'B00HGI16I4': ['B00ZJ5YDW2'],
#  'B00D0VMCXO': ['B00CSBQ5YO', 'B00AXLV0CI'],
#  'B00GSJ4AVM': ['B00ALTVJ8W', 'B00DVWRDN6', 'B00IJFYICO'],
#  'B00UZSTI28': ['B00DKAQ9JS', 'B01FIGE8YE', 'B00NZLNUXA', 'B0195SIAG8'],
#  'B00P86LM80': ['B00TEPG4HK', 'B00PMRE188'],
#  'B00OFA7YEQ': ['B00TBTC3HO', 'B00KVQZSF0'],
#  'B00BSW7PU2': ['B00PMOM70U', 'B00CVS2KH0'],
#  'B01GCULNK2': ['B014JSBJJ4', 'B017DGXD0M', 'B01AWPTL0W', 'B00OQY2X06'],
#  'B00GT4I4L8': ['B006FKBCOM', 'B00BB1BFCE', 'B00CK98XXK'],
#  'B00JO4GO94': ['B00PBVRFUQ', 'B00HCK1TZQ'],
#  'B00F2TFH5W': ['B00L01GJAS', 'B00OYWP438', 'B00CCVVKMW'],
#  'B00KQ4FVLS': ['B00IGVA8SE'],
#  'B004VF69LY': ['B00CBWM0BW'],
#  'B00A3ZA4TO': ['B00CQB2IPG'],
#  'B00OM12RWM': ['B00P86K18M', 'B00P86K1J6', 'B00PMDOW54', 'B00QESA0OI'],
#  'B004INHR24': ['B00KE62080'],
#  'B00TO2TRV8': ['B00E7CW6ZE'],
#  'B01645ZYZU': ['B0117VIQRE',
#   'B0150TBQYY',
#   'B00WDD5IKO',
#   'B012V5X57G',
#   'B00TJCFIFM',
#   'B00ZTMRHQ4',
#   'B00VH4UFMG'],
#  'B00EV9LSJI': ['B01ACTBA8E', 'B01GF9OSI4', 'B0067A2S5C'],
#  'B00FA0SCM8': ['B00GJCNLWC', 'B00EDCR48M'],
#  'B007Z3QVGW': ['B00CDVZFRW', 'B00BY5XSIG', 'B00C53PC7Q', 'B00DLW4HYO'],
#  'B00OV81RS6': ['B00PCZC7F4'],
#  'B004V49BLU': ['B006VDVWFW', 'B00K40M50E', 'B0078IPNCW'],
#  'B007KTEF9Q': ['B00BH16SWU'],
#  'B015BIHKH6': ['B01F5KX678', 'B00G8UKDQ2'],
#  'B014GCDQ62': ['B00T7XXV3Y',
#   'B014T6L87E',
#   'B00U48LDN6',
#   'B00TU7C7K0',
#   'B01297KYDO'],
#  'B00PKKNHKK': ['B00CV6ZYLQ',
#   'B00L0LQCQ4',
#   'B00NRWI91U',
#   'B00A946MNQ',
#   'B00L2X37QS'],
#  'B00H8ERJ8C': ['B00TKOT3BO', 'B018A8EDV0'],
#  'B01DX3EA06': ['B00PD8LQ6G', 'B00CYRH3H0'],
#  'B00E8ZW9SY': ['B00BW73VVU', 'B00ESPZ2C4', 'B00DVYIQDA'],
#  'B0184I7L1U': ['B017J556C0'],
#  'B00L0LQCQ4': ['B00NRWI91U'],
#  'B00LI5X2QA': ['B00AWHG6E0'],
#  'B00UCANMJO': ['B00ZOLS5HU', 'B01ACTBA8E', 'B01HFUF1GK'],
#  'B00RM9EJ22': ['B00YN6XHMU'],
#  'B00L7EIGEA': ['B01430HD34', 'B00SSCJTH2', 'B00MQF5SLS'],
#  'B00MT7UIQI': ['B00I15VLI6', 'B00ZOL1DRO', 'B015UN87JC'],
#  'B00AUMSP46': ['B00LNLVLN0', 'B00VQR2NOW'],
#  'B00OI7NB02': ['B01GZ070A6', 'B00K56DJ16'],
#  'B00GJCNLWC': ['B00FA0SCM8', 'B00EDCR48M'],
#  'B00N00N4UK': ['B00MD4TX68', 'B00LUC227G', 'B00O27QJIE', 'B00JJY2XX0'],
#  'B015C8H12E': ['B00TWOW2GK'],
#  'B00OAN88H0': ['B00FBK17PQ', 'B00DZSOC62'],
#  'B018A8EDV0': ['B00H8ERJ8C', 'B01864DDVO', 'B00WDD5IKO'],
#  'B00I4PEHKC': ['B00A9FYVXS', 'B00R0SMBXY', 'B00DMLQH8I'],
#  'B00EYOTJPK': ['B00II3YH8W', 'B00C8EUHQS'],
#  'B017J556C0': ['B0184I7L1U'],
#  'B00Q79E1AI': ['B00DJK31TK'],
#  'B006MZH7XU': ['B007D788ZW', 'B00KSO4TKU'],
#  'B00INIXG66': ['B00JXW6GFE', 'B00PRA4CUM', 'B00AEDDSN4'],
#  'B007NBCCA0': ['B007YIZ2YA'],
#  'B00LH8I7PE': ['B005SZ171I'],
#  'B009JPPQ38': ['B009B3V1KA'],
#  'B00RKVCI7U': ['B00C4DGG22', 'B00AR3O6SM'],
#  'B00OHZ151W': ['B00QI8BV9W', 'B00JWTGGVC', 'B00KDKCMKI'],
#  'B00II3YH8W': ['B00EYOTJPK', 'B00KZ41KGY', 'B00Y9H7M0G', 'B00C8EUHQS'],
#  'B009B11BKW': ['B0098796PQ', 'B00AV4X9TO', 'B0093TFV08', 'B00R8EKHVS'],
#  'B00Q5DLY42': ['B0191WS0K4', 'B00YOAZYYY', 'B00C5R83E6', 'B00TJ3G4U4'],
#  'B01CV6HR2E': ['B01A1E8WO0'],
#  'B01GWMFSYM': ['B00HBX7DD6'],
#  'B01BNWGPRK': ['B00R8EKHVS'],
#  'B00QZHHE7E': ['B00WN3NBSU', 'B01EMF4FXG'],
#  'B00KLO64S2': ['B00Q6Q5ZP2'],
#  'B00DGCPWB6': ['B007LS0JQE', 'B00E8HL9WY', 'B00JAUVINY', 'B00VPAHRLO'],
#  'B00IOQQZQU': ['B009F19JFM', 'B00EECLODW', 'B00DL7P9FA'],
#  'B00VE5O30I': ['B00JCA3F88', 'B00L2FQEVG', 'B00IX5FCR0', 'B01DIF788U'],
#  'B00EMG3A00': ['B007YIZ2YA', 'B00M3GWXHW'],
#  'B00ECBS5OQ': ['B00H0GED9Q', 'B00GBIYX8A'],
#  ...}

# %%
tf_idf_recommendations.get('B00CDZU7SU')
# Out:
# ['B00HE4Z51Y',
#  'B00BL6CDCA',
#  'B0090W7ZB6',
#  'B00C2L7N4G',
#  'B00P32ZUAK',
#  'B0069FJE4S',
#  'B005LVV6DI']

# %%
# Create a dictionary to map ASINs to titles
asin_to_title = dict(zip(data_preprocessed['asin'], data_preprocessed['title']))

recommendations_with_titles = {}

# Iterate over the dictionary with ASIN values and replace both keys and values with titles
for key, value in tf_idf_recommendations.items():
    key_title = asin_to_title[key]  # Get the title corresponding to the key (ASIN)
    value_titles = [asin_to_title[asin] for asin in value]  # Get the titles corresponding to the values (ASINs)
    recommendations_with_titles[key_title] = value_titles

# %%
print("Top Recommendations based on the book 'Ward of the Vampire (Ward of the Vampire Serial Book 1) - Kindle edition':\n")

for i in recommendations_with_titles.get('Ward of the Vampire (Ward of the Vampire Serial Book 1) - Kindle edition'):
    print(i)
# Out:
# Top Recommendations based on the book 'Ward of the Vampire (Ward of the Vampire Serial Book 1) - Kindle edition':
#
# A Twitch of Tail (The Wiccan-Were-Bear Series Book 6) - Kindle edition
# Loving Lachlyn (Ashland Pride Two) - Kindle edition
# Seducing Samantha (Ashland Pride One) - Kindle edition
# Every Dawn Forever (Hyena Heat Two) - Kindle edition

# %% [markdown]
# # Hybrid Approach

# %%
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split
import pandas as pd
import numpy as np

# %% [markdown]
# ### Create artificially a colds-start Problem
# The cold start problem in recommender systems refers to the challenge of providing accurate recommendations for new users or items with limited interaction history.

# %%
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split
import pandas as pd

# Convert the DataFrame to a Surprise Dataset
reader = Reader(rating_scale=(1, 5))
data_ground_truth = Dataset.load_from_df(data_preprocessed[['reviewerID', 'asin', 'rating']], reader)

# Extract 10% of users and their entries
unique_users = data_preprocessed['reviewerID'].unique()
num_test_users = int(0.1 * len(unique_users))
test_users = np.random.choice(unique_users, num_test_users, replace=False)
test_entries = data_preprocessed[data_preprocessed['reviewerID'].isin(test_users)]

# Remove test users and their entries from the dataset
data_remaining = data_preprocessed[~data_preprocessed['reviewerID'].isin(test_users)]
#print(data_remaining['reviewerID'])

# Convert the DataFrame to a Surprise Dataset
data = Dataset.load_from_df(data_remaining[['reviewerID', 'asin', 'rating']], reader)

# Split the data into train and test sets using Surprise's train_test_split
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# Convert test_entries to the same format as testset
test_entries_tuples = [tuple(x) for x in test_entries[['reviewerID', 'asin', 'rating']].values]


# Load the additional rows into the Surprise Dataset object
testset+= test_entries_tuples

# %%
# Initialize empty sets to collect unique reviewer IDs
unique_users_train = set()
unique_users_test = set()

# Iterate through the trainset ratings and collect unique reviewer IDs
for (user_id, _, _) in trainset.all_ratings():
    unique_users_train.add(user_id)

# Iterate through the testset ratings and collect unique reviewer IDs
for (user_id, _, _) in testset:
    unique_users_test.add(user_id)

# Get the number of unique reviewer IDs in train and test sets
num_unique_users_train = len(unique_users_train)
num_unique_users_test = len(unique_users_test)
test_only_users_count = len(unique_users_test) - len(unique_users_train)
test_only_users = unique_users_test - unique_users_train

print("Number of unique reviewer IDs in train set:", num_unique_users_train)
print("Number of unique reviewer IDs in test set:", num_unique_users_test)
print("Users in test set but not in train set:", test_only_users_count)
print("Top ten users in test set but not in train set:")
for i, user_id in enumerate(test_only_users):
    if i < 20:
        print(user_id)
    else:
        break
# Out:
# Number of unique reviewer IDs in train set: 314
# Number of unique reviewer IDs in test set: 348
# Users in test set but not in train set: 34
# Top ten users in test set but not in train set:
# A1VF3B672MSQ4C
# A2W3RQOSC87P4A
# AR6WIPHVS5G3I
# A2C7W167DVNUKH
# A39N24TTLP6I48
# A376U5S8TKOE69
# A2JPS7EMNFKXOV
# AIQWMQ4JWKZ3T
# A3O7EX5CU264Y1
# A3QVW8NFY4C4I1
# A13LERNQ8R7267
# A3A7FF87LEVCQ1
# A36PA4XPATJSKX
# A13JQT6036JF
# A1SBQ0F7FSLWB0
# A1JLU5H1CCENWX
# A2UNMDJYXPEQZ3
# A1I96OYAUJ3HQE
# A916DXE9W36GF
# AV4HVQ5WUQ1Z1

# %% [markdown]
# Here we can see, that trainset contains user ids, that are not in the trainset. Therefore a cold-start problem will occur for memory-based approaches
#
# ## Hybrid Model
# This model consists of a Collaborative Filtering Model of choice, in this case, we used the User-Based Filtering with KNNWithMeans. The other recommendation are the top most popular books based on rating and number of reviews. The hybrid apporach aims to solve cold-start problem, meaning that when there is no data known about a user, the most popular books are going to be recommended.

# %%
def user_based_KNNWithMeans_recommender_system(trainset, testset, data):
    
    #Choose best algorithm based on grid search
    algo = KNNWithMeans(k=1, sim_options={'name': 'pearson', 'user_based': False})
    
    # Train the best model with the new parameters and evaluate the trained model on the test set
    test_pred = algo.fit(trainset).test(testset)

    # Calculate evaluation metrics
    print("User-based Model with KNNWithMeans: Test Set")
    accuracy.rmse(test_pred, verbose=True)
    accuracy.mae(test_pred, verbose=True)

    return test_pred

# %%
prediction_memory_based = user_based_KNNWithMeans_recommender_system(trainset,testset, data_ground_truth)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# User-based Model with KNNWithMeans: Test Set
# RMSE: 0.9608
# MAE:  0.7442

# %%
# Define the user ID to filter
target_user_id = 'A3QVW8NFY4C4I1'

# Filter predictions for the target user ID
user_predictions = [pred for pred in prediction_memory_based if pred.uid == target_user_id]

# Print the filtered predictions
for pred in user_predictions:
    print(pred)
# Out:
# user: A3QVW8NFY4C4I1 item: B00K6S71RG r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00BBQ2JPQ r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00BPB9L3U r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00DE50LTS r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00KBH7JDI r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00IMNWM3K r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00K40M50E r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B004EYT0UO r_ui = 4.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00A9HW1CY r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B006H9WBWI r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B006HT0TJ0 r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00J3GS5O0 r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00CW44YIQ r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00HZ5ZDX2 r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00G984VPW r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B006JDEK0I r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00AA3P7M8 r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00IFEMVHI r_ui = 4.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00AQR4R9M r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00JNHU0T2 r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B00A6KQUIK r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}
# user: A3QVW8NFY4C4I1 item: B005S1XTEA r_ui = 5.00   est = 4.27   {'was_impossible': True, 'reason': 'User and/or item is unknown.'}

# %% [markdown]
# In this output we can see: Cold-start problem leads to poor prediction

# %%
def top_popular_books(data_preprocessed, n=5):
    # Group by 'asin' and calculate the average rating and count of ratings for each book
    popular_books = data_preprocessed.groupby('asin').agg({'rating': ['mean', 'count']})
    popular_books.columns = ['avg_rating', 'rating_count']
    
    # Sort the books based on rating count and average rating
    popular_books = popular_books.sort_values(by=['rating_count', 'avg_rating'], ascending=False)
    
    # Get the top n popular books
    top_books = popular_books.head(n)
    
    # Return the top books as a list
    return top_books.index.tolist()

# Example usage:
top_popular_books = top_popular_books(data_preprocessed)

# %%
top_popular_books
# Out:
# ['B00J0CAR16', 'B00EC197UC', 'B00D9CMLNA', 'B00M0DQIEC', 'B00EAHZR5W']

# %%
from surprise import Prediction
from collections import defaultdict

def hybrid_recommendation(prediction_memory_based, top_popular_books):
    # Dictionary to store the count of deleted predictions for each user
    deleted_predictions_count = defaultdict(int)
    
    # New list to store valid predictions
    valid_predictions = []
    
    # Loop through all predictions
    for prediction in prediction_memory_based:
        # Check if the prediction was impossible
        if prediction.details['was_impossible']:
            # Increment the count of deleted predictions for this user
            deleted_predictions_count[prediction.uid] += 1
        else:
            # Add valid predictions to the new list
            valid_predictions.append(prediction)
    
    # Loop through deleted predictions count for each user
    for user_id, count in deleted_predictions_count.items():
        # Add new predictions based on top popular books for this user
        for i in range(min(count, 5)):
            if i < len(top_popular_books):
                new_prediction = Prediction(uid=user_id, iid=top_popular_books[i], r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False})
                valid_predictions.append(new_prediction)
    
    return valid_predictions

# %%
predictions = hybrid_recommendation(prediction_memory_based, top_popular_books)

# %%
# Define the user ID to filter
#target_user_id = 'A1JLU5H1CCENWX' using the same target id

# Filter predictions for the target user ID
user_predictions_hybrid = [pred for pred in predictions if pred.uid == target_user_id]

# Print the filtered predictions
for pred in user_predictions_hybrid:
    print(pred)
# Out:
# user: A3QVW8NFY4C4I1 item: B00J0CAR16 r_ui = None   est = 5.00   {'actual_k': 0, 'was_impossible': False}
# user: A3QVW8NFY4C4I1 item: B00EC197UC r_ui = None   est = 5.00   {'actual_k': 0, 'was_impossible': False}
# user: A3QVW8NFY4C4I1 item: B00D9CMLNA r_ui = None   est = 5.00   {'actual_k': 0, 'was_impossible': False}
# user: A3QVW8NFY4C4I1 item: B00M0DQIEC r_ui = None   est = 5.00   {'actual_k': 0, 'was_impossible': False}
# user: A3QVW8NFY4C4I1 item: B00EAHZR5W r_ui = None   est = 5.00   {'actual_k': 0, 'was_impossible': False}
# user: A3QVW8NFY4C4I1 item: B00J0CAR16 r_ui = None   est = 5.00   {'actual_k': 0, 'was_impossible': False}
# user: A3QVW8NFY4C4I1 item: B00EC197UC r_ui = None   est = 5.00   {'actual_k': 0, 'was_impossible': False}
# user: A3QVW8NFY4C4I1 item: B00D9CMLNA r_ui = None   est = 5.00   {'actual_k': 0, 'was_impossible': False}
# user: A3QVW8NFY4C4I1 item: B00M0DQIEC r_ui = None   est = 5.00   {'actual_k': 0, 'was_impossible': False}
# user: A3QVW8NFY4C4I1 item: B00EAHZR5W r_ui = None   est = 5.00   {'actual_k': 0, 'was_impossible': False}

# %%
import json
def serialize_predictions(predictions, filename):
    """
    Serialize a list of Prediction objects to JSON and save it to a file.

    Args:
    - predictions (list): List of Prediction objects.
    - filename (str): Name of the file to save the serialized predictions.

    Returns:
    - None
    """
    serialized_predictions = []
    for pred in predictions:
        serialized_prediction = {
            "uid": pred.uid,
            "iid": pred.iid,
            "r_ui": pred.r_ui,
            "est": pred.est,
            "details": pred.details
        }
        serialized_predictions.append(serialized_prediction)

    with open(filename, 'w') as json_file:
        json.dump(serialized_predictions, json_file)

# %%
serialize_predictions(predictions, '../data/hybrid_recommender_system.json')
